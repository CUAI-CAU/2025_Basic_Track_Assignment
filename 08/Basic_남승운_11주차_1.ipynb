# %% [markdown]
# ### 보팅 분류기

# %%
import pandas as pd

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

cancer = load_breast_cancer()

data_df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
data_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33            184.6
# 1                 0.05667  ...         24.99          23.41            158.8
# 2                 0.05999  ...         23.57          25.53            152.5
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
#
# [3 rows x 30 columns]

# %%
lr_clf = LogisticRegression(solver='liblinear') # 로지스틱 회귀
knn_clf = KNeighborsClassifier(n_neighbors=8) # KNN

vo_clf=VotingClassifier(estimators=[('LR', lr_clf), ('KNN', knn_clf)], voting='soft') # 소프트 보팅 방식 사용, 디폴트는 hard임

X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, test_size=0.2 , random_state= 156)

# VotingClassifier 학습/예측/평가. 
vo_clf.fit(X_train , y_train) #학습
pred = vo_clf.predict(X_test) #예측
print('Voting 분류기 정확도: {0:.4f}'.format(accuracy_score(y_test , pred))) #평가

# 개별 모델의 학습/예측/평가.
classifiers = [lr_clf, knn_clf]
for classifier in classifiers:
    classifier.fit(X_train , y_train)
    pred = classifier.predict(X_test)
    class_name= classifier.__class__.__name__
    print('{0} 정확도: {1:.4f}'.format(class_name, accuracy_score(y_test , pred)))
# Out:
# Voting 분류기 정확도: 0.9561
# LogisticRegression 정확도: 0.9474
# KNeighborsClassifier 정확도: 0.9386

# %% [markdown]
# #### 무조건 보팅분류기가 성능이 더 높은 것은 아님. 기반 분류기 중 가장 좋은 분류기의 성능이 더 좋을 수도 있다

# %% [markdown]
# ### 랜덤 포레스트

# %%
#앞에서 정의한 함수 재정의

def get_new_feature_name_df(old_feature_name_df):
    feature_dup_df = pd.DataFrame(data=old_feature_name_df.groupby('column_name').cumcount(),
                                  columns=['dup_cnt'])
    feature_dup_df = feature_dup_df.reset_index()
    new_feature_name_df = pd.merge(old_feature_name_df.reset_index(), feature_dup_df, how='outer')
    new_feature_name_df['column_name'] = new_feature_name_df[['column_name', 'dup_cnt']].apply(lambda x : x[0]+'_'+str(x[1]) 
                                                                                         if x[1] >0 else x[0] ,  axis=1)
    new_feature_name_df = new_feature_name_df.drop(['index'], axis=1)
    return new_feature_name_df

def get_human_dataset( ):
    
    # 각 데이터 파일들은 공백으로 분리되어 있으므로 read_csv에서 공백 문자를 sep으로 할당.
    feature_name_df = pd.read_csv('./human_activity/features.txt',sep='\s+', header=None,names=['column_index','column_name'])
    
    # 중복된 피처명을 수정하는 get_new_feature_name_df()를 이용, 신규 피처명 DataFrame생성. 
    new_feature_name_df = get_new_feature_name_df(feature_name_df)
    
    # DataFrame에 피처명을 컬럼으로 부여하기 위해 리스트 객체로 다시 변환
    feature_name = new_feature_name_df.iloc[:, 1].values.tolist()
    
    # 학습 피처 데이터 셋과 테스트 피처 데이터을 DataFrame으로 로딩. 컬럼명은 feature_name 적용
    X_train = pd.read_csv('./human_activity/train/X_train.txt',sep='\s+', names=feature_name )
    X_test = pd.read_csv('./human_activity/test/X_test.txt',sep='\s+', names=feature_name)
    
    # 학습 레이블과 테스트 레이블 데이터을 DataFrame으로 로딩하고 컬럼명은 action으로 부여
    y_train = pd.read_csv('./human_activity/train/y_train.txt',sep='\s+',header=None,names=['action'])
    y_test = pd.read_csv('./human_activity/test/y_test.txt',sep='\s+',header=None,names=['action'])
    
    # 로드된 학습/테스트용 DataFrame을 모두 반환 
    return X_train, X_test, y_train, y_test

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# 결정 트리에서 사용한 get_human_dataset( )을 이용해 학습/테스트용 DataFrame 반환
X_train, X_test, y_train, y_test = get_human_dataset()

# 랜덤 포레스트 학습 및 별도의 테스트 셋으로 예측 성능 평가
rf_clf = RandomForestClassifier(random_state=0)
rf_clf.fit(X_train , y_train)
pred = rf_clf.predict(X_test)
accuracy = accuracy_score(y_test , pred)
print('랜덤 포레스트 정확도: {0:.4f}'.format(accuracy))
# Out:
# 랜덤 포레스트 정확도: 0.9223

# %%
from sklearn.model_selection import GridSearchCV

params = {
    'n_estimators':[100],
    'max_depth' : [6, 8, 10, 12], 
    'min_samples_leaf' : [8, 12, 18 ],
    'min_samples_split' : [8, 16, 20]
}
# RandomForestClassifier 객체 생성 후 GridSearchCV 수행
rf_clf = RandomForestClassifier(random_state=0, n_jobs=-1)
grid_cv = GridSearchCV(rf_clf , param_grid=params , cv=2, n_jobs=-1 ) # 모든 CPU 코어 사용
grid_cv.fit(X_train , y_train)

print('최적 하이퍼 파라미터:\n', grid_cv.best_params_)
print('최고 예측 정확도: {0:.4f}'.format(grid_cv.best_score_))
# Out:
# 최적 하이퍼 파라미터:
#  {'max_depth': 10, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 100}
# 최고 예측 정확도: 0.9178

# %%
rf_clf1 = RandomForestClassifier(n_estimators=300, max_depth=10, min_samples_leaf=8, min_samples_split=8, random_state=0)
rf_clf1.fit(X_train , y_train)
pred = rf_clf1.predict(X_test)
print('예측 정확도: {0:.4f}'.format(accuracy_score(y_test , pred)))
# Out:
# 예측 정확도: 0.9165

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

ftr_importances_values = rf_clf1.feature_importances_
ftr_importances = pd.Series(ftr_importances_values,index=X_train.columns  )
ftr_top20 = ftr_importances.sort_values(ascending=False)[:20]

plt.figure(figsize=(8,6))
plt.title('Feature importances Top 20')
sns.barplot(x=ftr_top20 , y = ftr_top20.index)
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('rf_feature_importances_top20.tif', format='tif', dpi=300, bbox_inches='tight')

# %% [markdown]
# ### GBM

# %%
from sklearn.ensemble import GradientBoostingClassifier
import time
import warnings
warnings.filterwarnings('ignore')

X_train, X_test, y_train, y_test = get_human_dataset()

# GBM 수행 시간 측정을 위함. 시작 시간 설정.
start_time = time.time()

gb_clf = GradientBoostingClassifier(random_state=0)
gb_clf.fit(X_train , y_train)
gb_pred = gb_clf.predict(X_test)
gb_accuracy = accuracy_score(y_test, gb_pred)

print('GBM 정확도: {0:.4f}'.format(gb_accuracy))
print("GBM 수행 시간: {0:.1f} 초 ".format(time.time() - start_time))
# Out:
# GBM 정확도: 0.9376
# GBM 수행 시간: 2276.7 초

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb
from xgboost import XGBClassifier

# %%
import xgboost

print(xgboost.__version__)
# Out:
# 2.1.1

# %%
import xgboost as xgb
from xgboost import plot_importance
import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

#데이터 확인
dataset = load_breast_cancer()
X_features= dataset.data
y_label = dataset.target

cancer_df = pd.DataFrame(data=X_features, columns=dataset.feature_names)
cancer_df['target']= y_label
cancer_df.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33            184.6      2019.0
# 1                 0.05667  ...          23.41            158.8      1956.0
# 2                 0.05999  ...          25.53            152.5      1709.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
#
#    worst symmetry  worst fractal dimension  target
# 0          0.4601                  0.11890       0
# 1          0.2750                  0.08902       0
# 2          0.3613                  0.08758       0
#
# [3 rows x 31 columns]

# %%
print(dataset.target_names)
print(cancer_df['target'].value_counts())
# Out:
# ['malignant' 'benign']
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
X_features = cancer_df.iloc[:, :-1]
y_label = cancer_df.iloc[:, -1]

# 80%는 학습용 데이터, 20%는 테스트 데이터 추출
X_train, X_test, y_train, y_test=train_test_split(X_features, y_label,
                                         test_size=0.2, random_state=156 )

# =X_train, y_train 90%는 학습, 10%는 검증용 데이터로 분리
X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=156 )

print(X_train.shape , X_test.shape)
print(X_tr.shape, X_val.shape)
# Out:
# (455, 30) (114, 30)
# (409, 30) (46, 30)

# %%
dtr = xgb.DMatrix(data=X_tr, label=y_tr)
dval = xgb.DMatrix(data=X_val, label=y_val)
dtest = xgb.DMatrix(data=X_test , label=y_test)

# %%
params = { 'max_depth':3,
          'eta': 0.05,
          'objective':'binary:logistic',
          'eval_metric':'logloss'
         }
num_rounds = 400

# %%
eval_list = [(dtr,'train'),(dval,'eval')] 

xgb_model = xgb.train(params = params , dtrain=dtr , num_boost_round=num_rounds , early_stopping_rounds=50, evals=eval_list )
# Out:
# [0]	train-logloss:0.62480	eval-logloss:0.63104
# [1]	train-logloss:0.58674	eval-logloss:0.60478
# [2]	train-logloss:0.55226	eval-logloss:0.58223
# [3]	train-logloss:0.52086	eval-logloss:0.56184
# [4]	train-logloss:0.49192	eval-logloss:0.54118
# [5]	train-logloss:0.46537	eval-logloss:0.52223
# [6]	train-logloss:0.44029	eval-logloss:0.50287
# [7]	train-logloss:0.41666	eval-logloss:0.48620
# [8]	train-logloss:0.39525	eval-logloss:0.46974
# [9]	train-logloss:0.37542	eval-logloss:0.45497
# [10]	train-logloss:0.35701	eval-logloss:0.44131
# [11]	train-logloss:0.33982	eval-logloss:0.43134
# [12]	train-logloss:0.32297	eval-logloss:0.41972
# [13]	train-logloss:0.30725	eval-logloss:0.40902
# [14]	train-logloss:0.29327	eval-logloss:0.39883
# [15]	train-logloss:0.27946	eval-logloss:0.38968
# [16]	train-logloss:0.26691	eval-logloss:0.38150
# [17]	train-logloss:0.25473	eval-logloss:0.37368
# [18]	train-logloss:0.24385	eval-logloss:0.36666
# [19]	train-logloss:0.23338	eval-logloss:0.35994
# [20]	train-logloss:0.22320	eval-logloss:0.35374
# [21]	train-logloss:0.21363	eval-logloss:0.34704
# [22]	train-logloss:0.20487	eval-logloss:0.34206
# [23]	train-logloss:0.19634	eval-logloss:0.33621
# [24]	train-logloss:0.18830	eval-logloss:0.33178
# [25]	train-logloss:0.18093	eval-logloss:0.32774
# [26]	train-logloss:0.17374	eval-logloss:0.32297
# [27]	train-logloss:0.16695	eval-logloss:0.31855
# [28]	train-logloss:0.16059	eval-logloss:0.31495
# [29]	train-logloss:0.15450	eval-logloss:0.31173
# [30]	train-logloss:0.14875	eval-logloss:0.30735
# [31]	train-logloss:0.14329	eval-logloss:0.30463
# [32]	train-logloss:0.13807	eval-logloss:0.30242
# [33]	train-logloss:0.13325	eval-logloss:0.29922
# [34]	train-logloss:0.12864	eval-logloss:0.29722
# [35]	train-logloss:0.12429	eval-logloss:0.29540
# [36]	train-logloss:0.12000	eval-logloss:0.29300
# [37]	train-logloss:0.11581	eval-logloss:0.29010
# [38]	train-logloss:0.11210	eval-logloss:0.28883
# [39]	train-logloss:0.10838	eval-logloss:0.28769
# [40]	train-logloss:0.10481	eval-logloss:0.28574
# [41]	train-logloss:0.10160	eval-logloss:0.28434
# [42]	train-logloss:0.09832	eval-logloss:0.28226
# [43]	train-logloss:0.09534	eval-logloss:0.28006
# [44]	train-logloss:0.09249	eval-logloss:0.27854
# [45]	train-logloss:0.08972	eval-logloss:0.27747
# [46]	train-logloss:0.08700	eval-logloss:0.27654
# [47]	train-logloss:0.08461	eval-logloss:0.27598
# [48]	train-logloss:0.08225	eval-logloss:0.27415
# [49]	train-logloss:0.08001	eval-logloss:0.27245
# [50]	train-logloss:0.07784	eval-logloss:0.27104
# [51]	train-logloss:0.07578	eval-logloss:0.26958
# [52]	train-logloss:0.07384	eval-logloss:0.26869
# [53]	train-logloss:0.07196	eval-logloss:0.26760
# [54]	train-logloss:0.07021	eval-logloss:0.26661
# [55]	train-logloss:0.06833	eval-logloss:0.26680
# [56]	train-logloss:0.06671	eval-logloss:0.26517
# [57]	train-logloss:0.06519	eval-logloss:0.26412
# [58]	train-logloss:0.06368	eval-logloss:0.26444
# [59]	train-logloss:0.06202	eval-logloss:0.26434
# [60]	train-logloss:0.06048	eval-logloss:0.26208
# [61]	train-logloss:0.05898	eval-logloss:0.26139
# [62]	train-logloss:0.05756	eval-logloss:0.26155
# [63]	train-logloss:0.05614	eval-logloss:0.26114
# [64]	train-logloss:0.05486	eval-logloss:0.25973
# [65]	train-logloss:0.05372	eval-logloss:0.25878
# [66]	train-logloss:0.05263	eval-logloss:0.25758
# [67]	train-logloss:0.05140	eval-logloss:0.25664
# [68]	train-logloss:0.05019	eval-logloss:0.25625
# [69]	train-logloss:0.04910	eval-logloss:0.25593
# [70]	train-logloss:0.04806	eval-logloss:0.25438
# [71]	train-logloss:0.04704	eval-logloss:0.25373
# [72]	train-logloss:0.04606	eval-logloss:0.25411
# [73]	train-logloss:0.04514	eval-logloss:0.25316
# [74]	train-logloss:0.04435	eval-logloss:0.25248
# [75]	train-logloss:0.04347	eval-logloss:0.25271
# [76]	train-logloss:0.04260	eval-logloss:0.25282
# [77]	train-logloss:0.04178	eval-logloss:0.25165
# [78]	train-logloss:0.04099	eval-logloss:0.25181
# [79]	train-logloss:0.04022	eval-logloss:0.25210
# [80]	train-logloss:0.03942	eval-logloss:0.25194
# [81]	train-logloss:0.03875	eval-logloss:0.25254
# [82]	train-logloss:0.03799	eval-logloss:0.25264
# [83]	train-logloss:0.03727	eval-logloss:0.25280
# [84]	train-logloss:0.03657	eval-logloss:0.25281
# [85]	train-logloss:0.03586	eval-logloss:0.25219
# [86]	train-logloss:0.03530	eval-logloss:0.25288
# [87]	train-logloss:0.03464	eval-logloss:0.25226
# [88]	train-logloss:0.03401	eval-logloss:0.25167
# [89]	train-logloss:0.03347	eval-logloss:0.25258
# [90]	train-logloss:0.03297	eval-logloss:0.25331
# [91]	train-logloss:0.03240	eval-logloss:0.25373
# [92]	train-logloss:0.03184	eval-logloss:0.25323
# [93]	train-logloss:0.03136	eval-logloss:0.25240
# [94]	train-logloss:0.03086	eval-logloss:0.25324
# [95]	train-logloss:0.03035	eval-logloss:0.25280
# [96]	train-logloss:0.02985	eval-logloss:0.25215
# [97]	train-logloss:0.02937	eval-logloss:0.25179
# [98]	train-logloss:0.02892	eval-logloss:0.25143
# [99]	train-logloss:0.02853	eval-logloss:0.25180
# [100]	train-logloss:0.02810	eval-logloss:0.25151
# [101]	train-logloss:0.02769	eval-logloss:0.25158
# [102]	train-logloss:0.02729	eval-logloss:0.25130
# [103]	train-logloss:0.02689	eval-logloss:0.25094
# [104]	train-logloss:0.02654	eval-logloss:0.25054
# [105]	train-logloss:0.02617	eval-logloss:0.25030
# [106]	train-logloss:0.02580	eval-logloss:0.24850
# [107]	train-logloss:0.02545	eval-logloss:0.24829
# [108]	train-logloss:0.02509	eval-logloss:0.24828
# [109]	train-logloss:0.02475	eval-logloss:0.24881
# [110]	train-logloss:0.02443	eval-logloss:0.24912
# [111]	train-logloss:0.02405	eval-logloss:0.24791
# [112]	train-logloss:0.02374	eval-logloss:0.24846
# [113]	train-logloss:0.02341	eval-logloss:0.24931
# [114]	train-logloss:0.02314	eval-logloss:0.24832
# [115]	train-logloss:0.02286	eval-logloss:0.24889
# [116]	train-logloss:0.02255	eval-logloss:0.24866
# [117]	train-logloss:0.02227	eval-logloss:0.24925
# [118]	train-logloss:0.02197	eval-logloss:0.24679
# [119]	train-logloss:0.02172	eval-logloss:0.24787
# [120]	train-logloss:0.02141	eval-logloss:0.24846
# [121]	train-logloss:0.02112	eval-logloss:0.24683
# [122]	train-logloss:0.02088	eval-logloss:0.24650
# [123]	train-logloss:0.02061	eval-logloss:0.24497
# [124]	train-logloss:0.02037	eval-logloss:0.24529
# [125]	train-logloss:0.02012	eval-logloss:0.24516
# [126]	train-logloss:0.01987	eval-logloss:0.24576
# [127]	train-logloss:0.01967	eval-logloss:0.24576
# [128]	train-logloss:0.01943	eval-logloss:0.24563
# [129]	train-logloss:0.01922	eval-logloss:0.24533
# [130]	train-logloss:0.01900	eval-logloss:0.24591
# [131]	train-logloss:0.01881	eval-logloss:0.24593
# [132]	train-logloss:0.01858	eval-logloss:0.24582
# [133]	train-logloss:0.01839	eval-logloss:0.24619
# [134]	train-logloss:0.01824	eval-logloss:0.24631
# [135]	train-logloss:0.01805	eval-logloss:0.24669
# [136]	train-logloss:0.01785	eval-logloss:0.24660
# [137]	train-logloss:0.01770	eval-logloss:0.24584
# [138]	train-logloss:0.01753	eval-logloss:0.24465
# [139]	train-logloss:0.01734	eval-logloss:0.24458
# [140]	train-logloss:0.01720	eval-logloss:0.24385
# [141]	train-logloss:0.01703	eval-logloss:0.24422
# [142]	train-logloss:0.01690	eval-logloss:0.24423
# [143]	train-logloss:0.01673	eval-logloss:0.24408
# [144]	train-logloss:0.01655	eval-logloss:0.24381
# [145]	train-logloss:0.01641	eval-logloss:0.24311
# [146]	train-logloss:0.01629	eval-logloss:0.24322
# [147]	train-logloss:0.01614	eval-logloss:0.24360
# [148]	train-logloss:0.01597	eval-logloss:0.24328
# [149]	train-logloss:0.01582	eval-logloss:0.24314
# [150]	train-logloss:0.01571	eval-logloss:0.24315
# [151]	train-logloss:0.01556	eval-logloss:0.24289
# [152]	train-logloss:0.01537	eval-logloss:0.24363
# [153]	train-logloss:0.01523	eval-logloss:0.24404
# [154]	train-logloss:0.01510	eval-logloss:0.24383
# [155]	train-logloss:0.01493	eval-logloss:0.24435
# [156]	train-logloss:0.01478	eval-logloss:0.24425
# [157]	train-logloss:0.01467	eval-logloss:0.24361
# [158]	train-logloss:0.01455	eval-logloss:0.24294
# [159]	train-logloss:0.01440	eval-logloss:0.24340
# [160]	train-logloss:0.01428	eval-logloss:0.24323
# [161]	train-logloss:0.01417	eval-logloss:0.24310
# [162]	train-logloss:0.01409	eval-logloss:0.24247
# [163]	train-logloss:0.01393	eval-logloss:0.24311
# [164]	train-logloss:0.01380	eval-logloss:0.24269
# [165]	train-logloss:0.01368	eval-logloss:0.24268
# [166]	train-logloss:0.01360	eval-logloss:0.24242
# [167]	train-logloss:0.01345	eval-logloss:0.24306
# [168]	train-logloss:0.01335	eval-logloss:0.24220
# [169]	train-logloss:0.01328	eval-logloss:0.24116
# [170]	train-logloss:0.01317	eval-logloss:0.24117
# [171]	train-logloss:0.01308	eval-logloss:0.24126
# [172]	train-logloss:0.01299	eval-logloss:0.24046
# [173]	train-logloss:0.01292	eval-logloss:0.23993
# [174]	train-logloss:0.01284	eval-logloss:0.23985
# [175]	train-logloss:0.01275	eval-logloss:0.23994
# [176]	train-logloss:0.01268	eval-logloss:0.23986
# [177]	train-logloss:0.01260	eval-logloss:0.23996
# [178]	train-logloss:0.01253	eval-logloss:0.23943
# [179]	train-logloss:0.01243	eval-logloss:0.23847
# [180]	train-logloss:0.01236	eval-logloss:0.23842
# [181]	train-logloss:0.01226	eval-logloss:0.23885
# [182]	train-logloss:0.01220	eval-logloss:0.23828
# [183]	train-logloss:0.01214	eval-logloss:0.23892
# [184]	train-logloss:0.01205	eval-logloss:0.23804
# [185]	train-logloss:0.01198	eval-logloss:0.23799
# [186]	train-logloss:0.01191	eval-logloss:0.23809
# [187]	train-logloss:0.01185	eval-logloss:0.23752
# [188]	train-logloss:0.01176	eval-logloss:0.23662
# [189]	train-logloss:0.01170	eval-logloss:0.23659
# [190]	train-logloss:0.01163	eval-logloss:0.23668
# [191]	train-logloss:0.01157	eval-logloss:0.23732
# [192]	train-logloss:0.01152	eval-logloss:0.23726
# [193]	train-logloss:0.01146	eval-logloss:0.23722
# [194]	train-logloss:0.01141	eval-logloss:0.23715
# [195]	train-logloss:0.01136	eval-logloss:0.23661
# [196]	train-logloss:0.01128	eval-logloss:0.23673
# [197]	train-logloss:0.01126	eval-logloss:0.23651
# [198]	train-logloss:0.01120	eval-logloss:0.23628
# [199]	train-logloss:0.01113	eval-logloss:0.23641
# [200]	train-logloss:0.01108	eval-logloss:0.23554
# [201]	train-logloss:0.01103	eval-logloss:0.23533
# [202]	train-logloss:0.01097	eval-logloss:0.23543
# [203]	train-logloss:0.01091	eval-logloss:0.23546
# [204]	train-logloss:0.01086	eval-logloss:0.23588
# [205]	train-logloss:0.01079	eval-logloss:0.23600
# [206]	train-logloss:0.01074	eval-logloss:0.23578
# [207]	train-logloss:0.01069	eval-logloss:0.23597
# [208]	train-logloss:0.01064	eval-logloss:0.23601
# [209]	train-logloss:0.01058	eval-logloss:0.23613
# [210]	train-logloss:0.01054	eval-logloss:0.23592
# [211]	train-logloss:0.01047	eval-logloss:0.23605
# [212]	train-logloss:0.01045	eval-logloss:0.23586
# [213]	train-logloss:0.01041	eval-logloss:0.23626
# [214]	train-logloss:0.01036	eval-logloss:0.23646
# [215]	train-logloss:0.01031	eval-logloss:0.23649
# [216]	train-logloss:0.01026	eval-logloss:0.23697
# [217]	train-logloss:0.01024	eval-logloss:0.23679
# [218]	train-logloss:0.01019	eval-logloss:0.23689
# [219]	train-logloss:0.01014	eval-logloss:0.23693
# [220]	train-logloss:0.01011	eval-logloss:0.23714
# [221]	train-logloss:0.01006	eval-logloss:0.23732
# [222]	train-logloss:0.01004	eval-logloss:0.23714
# [223]	train-logloss:0.01001	eval-logloss:0.23736
# [224]	train-logloss:0.00999	eval-logloss:0.23711
# [225]	train-logloss:0.00997	eval-logloss:0.23703
# [226]	train-logloss:0.00994	eval-logloss:0.23757
# [227]	train-logloss:0.00992	eval-logloss:0.23740
# [228]	train-logloss:0.00986	eval-logloss:0.23673
# [229]	train-logloss:0.00984	eval-logloss:0.23649
# [230]	train-logloss:0.00981	eval-logloss:0.23670
# [231]	train-logloss:0.00979	eval-logloss:0.23653
# [232]	train-logloss:0.00975	eval-logloss:0.23671
# [233]	train-logloss:0.00971	eval-logloss:0.23674
# [234]	train-logloss:0.00968	eval-logloss:0.23696
# [235]	train-logloss:0.00966	eval-logloss:0.23673
# [236]	train-logloss:0.00964	eval-logloss:0.23656
# [237]	train-logloss:0.00961	eval-logloss:0.23708
# [238]	train-logloss:0.00957	eval-logloss:0.23764
# [239]	train-logloss:0.00954	eval-logloss:0.23766
# [240]	train-logloss:0.00949	eval-logloss:0.23778
# [241]	train-logloss:0.00948	eval-logloss:0.23775
# [242]	train-logloss:0.00945	eval-logloss:0.23796
# [243]	train-logloss:0.00943	eval-logloss:0.23780
# [244]	train-logloss:0.00941	eval-logloss:0.23827
# [245]	train-logloss:0.00940	eval-logloss:0.23819
# [246]	train-logloss:0.00937	eval-logloss:0.23840
# [247]	train-logloss:0.00935	eval-logloss:0.23838
# [248]	train-logloss:0.00933	eval-logloss:0.23821
# [249]	train-logloss:0.00931	eval-logloss:0.23872
# [250]	train-logloss:0.00925	eval-logloss:0.23805

# %%
pred_probs = xgb_model.predict(dtest)
print('predict( ) 수행 결과값을 10개만 표시, 예측 확률 값으로 표시됨')
print(np.round(pred_probs[:10],3))

# 예측 확률이 0.5 보다 크면 1 , 그렇지 않으면 0 으로 예측값 결정하여 List 객체인 preds에 저장 
preds = [ 1 if x > 0.5 else 0 for x in pred_probs ]
print('예측값 10개만 표시:',preds[:10])
# Out:
# predict( ) 수행 결과값을 10개만 표시, 예측 확률 값으로 표시됨
# [0.938 0.004 0.75  0.049 0.98  1.    0.999 0.999 0.998 0.001]
# 예측값 10개만 표시: [1, 0, 1, 0, 1, 1, 1, 1, 1, 0]

# %%
# 3장의 함수 재정의

from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f}, F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.1, max_depth=3, eval_metric='logloss')
xgb_wrapper.fit(X_train, y_train)
w_preds = xgb_wrapper.predict(X_test)
w_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

# %%
get_clf_eval(y_test, w_preds, w_pred_proba)
# Out:
# 오차 행렬
# [[35  2]
#  [ 1 76]]
# 정확도: 0.9737, 정밀도: 0.9744, 재현율: 0.9870,    F1: 0.9806, AUC:0.9947

# %%
xgb_wrapper = XGBClassifier(n_estimators=400, learning_rate=0.05, max_depth=3)
evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, eval_set=evals, verbose=True)

ws50_preds = xgb_wrapper.predict(X_test)
ws50_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [0]	validation_0-logloss:0.62480	validation_1-logloss:0.63104
# [1]	validation_0-logloss:0.58674	validation_1-logloss:0.60478
# [2]	validation_0-logloss:0.55226	validation_1-logloss:0.58223
# [3]	validation_0-logloss:0.52086	validation_1-logloss:0.56184
# [4]	validation_0-logloss:0.49192	validation_1-logloss:0.54118
# [5]	validation_0-logloss:0.46537	validation_1-logloss:0.52223
# [6]	validation_0-logloss:0.44029	validation_1-logloss:0.50287
# [7]	validation_0-logloss:0.41666	validation_1-logloss:0.48620
# [8]	validation_0-logloss:0.39525	validation_1-logloss:0.46974
# [9]	validation_0-logloss:0.37542	validation_1-logloss:0.45497
# [10]	validation_0-logloss:0.35701	validation_1-logloss:0.44131
# [11]	validation_0-logloss:0.33982	validation_1-logloss:0.43134
# [12]	validation_0-logloss:0.32297	validation_1-logloss:0.41972
# [13]	validation_0-logloss:0.30725	validation_1-logloss:0.40902
# [14]	validation_0-logloss:0.29327	validation_1-logloss:0.39883
# [15]	validation_0-logloss:0.27946	validation_1-logloss:0.38968
# [16]	validation_0-logloss:0.26691	validation_1-logloss:0.38150
# [17]	validation_0-logloss:0.25473	validation_1-logloss:0.37368
# [18]	validation_0-logloss:0.24385	validation_1-logloss:0.36666
# [19]	validation_0-logloss:0.23338	validation_1-logloss:0.35994
# [20]	validation_0-logloss:0.22320	validation_1-logloss:0.35374
# [21]	validation_0-logloss:0.21363	validation_1-logloss:0.34704
# [22]	validation_0-logloss:0.20487	validation_1-logloss:0.34206
# [23]	validation_0-logloss:0.19634	validation_1-logloss:0.33621
# [24]	validation_0-logloss:0.18830	validation_1-logloss:0.33178
# [25]	validation_0-logloss:0.18093	validation_1-logloss:0.32774
# [26]	validation_0-logloss:0.17374	validation_1-logloss:0.32297
# [27]	validation_0-logloss:0.16695	validation_1-logloss:0.31855
# [28]	validation_0-logloss:0.16059	validation_1-logloss:0.31495
# [29]	validation_0-logloss:0.15450	validation_1-logloss:0.31173
# [30]	validation_0-logloss:0.14875	validation_1-logloss:0.30735
# [31]	validation_0-logloss:0.14329	validation_1-logloss:0.30463
# [32]	validation_0-logloss:0.13807	validation_1-logloss:0.30242
# [33]	validation_0-logloss:0.13325	validation_1-logloss:0.29922
# [34]	validation_0-logloss:0.12864	validation_1-logloss:0.29722
# [35]	validation_0-logloss:0.12429	validation_1-logloss:0.29540
# [36]	validation_0-logloss:0.12000	validation_1-logloss:0.29300
# [37]	validation_0-logloss:0.11581	validation_1-logloss:0.29010
# [38]	validation_0-logloss:0.11210	validation_1-logloss:0.28883
# [39]	validation_0-logloss:0.10838	validation_1-logloss:0.28769
# [40]	validation_0-logloss:0.10481	validation_1-logloss:0.28574
# [41]	validation_0-logloss:0.10160	validation_1-logloss:0.28434
# [42]	validation_0-logloss:0.09832	validation_1-logloss:0.28226
# [43]	validation_0-logloss:0.09534	validation_1-logloss:0.28006
# [44]	validation_0-logloss:0.09249	validation_1-logloss:0.27854
# [45]	validation_0-logloss:0.08972	validation_1-logloss:0.27747
# [46]	validation_0-logloss:0.08700	validation_1-logloss:0.27654
# [47]	validation_0-logloss:0.08461	validation_1-logloss:0.27598
# [48]	validation_0-logloss:0.08225	validation_1-logloss:0.27415
# [49]	validation_0-logloss:0.08001	validation_1-logloss:0.27245
# [50]	validation_0-logloss:0.07784	validation_1-logloss:0.27104
# [51]	validation_0-logloss:0.07578	validation_1-logloss:0.26958
# [52]	validation_0-logloss:0.07384	validation_1-logloss:0.26869
# [53]	validation_0-logloss:0.07196	validation_1-logloss:0.26760
# [54]	validation_0-logloss:0.07021	validation_1-logloss:0.26661
# [55]	validation_0-logloss:0.06833	validation_1-logloss:0.26680
# [56]	validation_0-logloss:0.06671	validation_1-logloss:0.26517
# [57]	validation_0-logloss:0.06519	validation_1-logloss:0.26412
# [58]	validation_0-logloss:0.06368	validation_1-logloss:0.26444
# [59]	validation_0-logloss:0.06202	validation_1-logloss:0.26434
# [60]	validation_0-logloss:0.06048	validation_1-logloss:0.26208
# [61]	validation_0-logloss:0.05898	validation_1-logloss:0.26139
# [62]	validation_0-logloss:0.05756	validation_1-logloss:0.26155
# [63]	validation_0-logloss:0.05614	validation_1-logloss:0.26114
# [64]	validation_0-logloss:0.05486	validation_1-logloss:0.25973
# [65]	validation_0-logloss:0.05372	validation_1-logloss:0.25878
# [66]	validation_0-logloss:0.05263	validation_1-logloss:0.25758
# [67]	validation_0-logloss:0.05140	validation_1-logloss:0.25664
# [68]	validation_0-logloss:0.05019	validation_1-logloss:0.25625
# [69]	validation_0-logloss:0.04910	validation_1-logloss:0.25593
# [70]	validation_0-logloss:0.04806	validation_1-logloss:0.25438
# [71]	validation_0-logloss:0.04704	validation_1-logloss:0.25373
# [72]	validation_0-logloss:0.04606	validation_1-logloss:0.25411
# [73]	validation_0-logloss:0.04514	validation_1-logloss:0.25316
# [74]	validation_0-logloss:0.04435	validation_1-logloss:0.25248
# [75]	validation_0-logloss:0.04347	validation_1-logloss:0.25271
# [76]	validation_0-logloss:0.04260	validation_1-logloss:0.25282
# [77]	validation_0-logloss:0.04178	validation_1-logloss:0.25165
# [78]	validation_0-logloss:0.04099	validation_1-logloss:0.25181
# [79]	validation_0-logloss:0.04022	validation_1-logloss:0.25210
# [80]	validation_0-logloss:0.03942	validation_1-logloss:0.25194
# [81]	validation_0-logloss:0.03875	validation_1-logloss:0.25254
# [82]	validation_0-logloss:0.03799	validation_1-logloss:0.25264
# [83]	validation_0-logloss:0.03727	validation_1-logloss:0.25280
# [84]	validation_0-logloss:0.03657	validation_1-logloss:0.25281
# [85]	validation_0-logloss:0.03586	validation_1-logloss:0.25219
# [86]	validation_0-logloss:0.03530	validation_1-logloss:0.25288
# [87]	validation_0-logloss:0.03464	validation_1-logloss:0.25226
# [88]	validation_0-logloss:0.03401	validation_1-logloss:0.25167
# [89]	validation_0-logloss:0.03347	validation_1-logloss:0.25258
# [90]	validation_0-logloss:0.03297	validation_1-logloss:0.25331
# [91]	validation_0-logloss:0.03240	validation_1-logloss:0.25373
# [92]	validation_0-logloss:0.03184	validation_1-logloss:0.25323
# [93]	validation_0-logloss:0.03136	validation_1-logloss:0.25240
# [94]	validation_0-logloss:0.03086	validation_1-logloss:0.25324
# [95]	validation_0-logloss:0.03035	validation_1-logloss:0.25280
# [96]	validation_0-logloss:0.02985	validation_1-logloss:0.25215
# [97]	validation_0-logloss:0.02937	validation_1-logloss:0.25179
# [98]	validation_0-logloss:0.02892	validation_1-logloss:0.25143
# [99]	validation_0-logloss:0.02853	validation_1-logloss:0.25180
# [100]	validation_0-logloss:0.02810	validation_1-logloss:0.25151
# [101]	validation_0-logloss:0.02769	validation_1-logloss:0.25158
# [102]	validation_0-logloss:0.02729	validation_1-logloss:0.25130
# [103]	validation_0-logloss:0.02689	validation_1-logloss:0.25094
# [104]	validation_0-logloss:0.02654	validation_1-logloss:0.25054
# [105]	validation_0-logloss:0.02617	validation_1-logloss:0.25030
# [106]	validation_0-logloss:0.02580	validation_1-logloss:0.24850
# [107]	validation_0-logloss:0.02545	validation_1-logloss:0.24829
# [108]	validation_0-logloss:0.02509	validation_1-logloss:0.24828
# [109]	validation_0-logloss:0.02475	validation_1-logloss:0.24881
# [110]	validation_0-logloss:0.02443	validation_1-logloss:0.24912
# [111]	validation_0-logloss:0.02405	validation_1-logloss:0.24791
# [112]	validation_0-logloss:0.02374	validation_1-logloss:0.24846
# [113]	validation_0-logloss:0.02341	validation_1-logloss:0.24931
# [114]	validation_0-logloss:0.02314	validation_1-logloss:0.24832
# [115]	validation_0-logloss:0.02286	validation_1-logloss:0.24889
# [116]	validation_0-logloss:0.02255	validation_1-logloss:0.24866
# [117]	validation_0-logloss:0.02227	validation_1-logloss:0.24925
# [118]	validation_0-logloss:0.02197	validation_1-logloss:0.24679
# [119]	validation_0-logloss:0.02172	validation_1-logloss:0.24787
# [120]	validation_0-logloss:0.02141	validation_1-logloss:0.24846
# [121]	validation_0-logloss:0.02112	validation_1-logloss:0.24683
# [122]	validation_0-logloss:0.02088	validation_1-logloss:0.24650
# [123]	validation_0-logloss:0.02061	validation_1-logloss:0.24497
# [124]	validation_0-logloss:0.02037	validation_1-logloss:0.24529
# [125]	validation_0-logloss:0.02012	validation_1-logloss:0.24516
# [126]	validation_0-logloss:0.01987	validation_1-logloss:0.24576
# [127]	validation_0-logloss:0.01967	validation_1-logloss:0.24576
# [128]	validation_0-logloss:0.01943	validation_1-logloss:0.24563
# [129]	validation_0-logloss:0.01922	validation_1-logloss:0.24533
# [130]	validation_0-logloss:0.01900	validation_1-logloss:0.24591
# [131]	validation_0-logloss:0.01881	validation_1-logloss:0.24593
# [132]	validation_0-logloss:0.01858	validation_1-logloss:0.24582
# [133]	validation_0-logloss:0.01839	validation_1-logloss:0.24619
# [134]	validation_0-logloss:0.01824	validation_1-logloss:0.24631
# [135]	validation_0-logloss:0.01805	validation_1-logloss:0.24669
# [136]	validation_0-logloss:0.01785	validation_1-logloss:0.24660
# [137]	validation_0-logloss:0.01770	validation_1-logloss:0.24584
# [138]	validation_0-logloss:0.01753	validation_1-logloss:0.24465
# [139]	validation_0-logloss:0.01734	validation_1-logloss:0.24458
# [140]	validation_0-logloss:0.01720	validation_1-logloss:0.24385
# [141]	validation_0-logloss:0.01703	validation_1-logloss:0.24422
# [142]	validation_0-logloss:0.01690	validation_1-logloss:0.24423
# [143]	validation_0-logloss:0.01673	validation_1-logloss:0.24408
# [144]	validation_0-logloss:0.01655	validation_1-logloss:0.24381
# [145]	validation_0-logloss:0.01641	validation_1-logloss:0.24311
# [146]	validation_0-logloss:0.01629	validation_1-logloss:0.24322
# [147]	validation_0-logloss:0.01614	validation_1-logloss:0.24360
# [148]	validation_0-logloss:0.01597	validation_1-logloss:0.24328
# [149]	validation_0-logloss:0.01582	validation_1-logloss:0.24314
# [150]	validation_0-logloss:0.01571	validation_1-logloss:0.24315
# [151]	validation_0-logloss:0.01556	validation_1-logloss:0.24289
# [152]	validation_0-logloss:0.01537	validation_1-logloss:0.24363
# [153]	validation_0-logloss:0.01523	validation_1-logloss:0.24404
# [154]	validation_0-logloss:0.01510	validation_1-logloss:0.24383
# [155]	validation_0-logloss:0.01493	validation_1-logloss:0.24435
# [156]	validation_0-logloss:0.01478	validation_1-logloss:0.24425
# [157]	validation_0-logloss:0.01467	validation_1-logloss:0.24361
# [158]	validation_0-logloss:0.01455	validation_1-logloss:0.24294
# [159]	validation_0-logloss:0.01440	validation_1-logloss:0.24340
# [160]	validation_0-logloss:0.01428	validation_1-logloss:0.24323
# [161]	validation_0-logloss:0.01417	validation_1-logloss:0.24310
# [162]	validation_0-logloss:0.01409	validation_1-logloss:0.24247
# [163]	validation_0-logloss:0.01393	validation_1-logloss:0.24311
# [164]	validation_0-logloss:0.01380	validation_1-logloss:0.24269
# [165]	validation_0-logloss:0.01368	validation_1-logloss:0.24268
# [166]	validation_0-logloss:0.01360	validation_1-logloss:0.24242
# [167]	validation_0-logloss:0.01345	validation_1-logloss:0.24306
# [168]	validation_0-logloss:0.01335	validation_1-logloss:0.24220
# [169]	validation_0-logloss:0.01328	validation_1-logloss:0.24116
# [170]	validation_0-logloss:0.01317	validation_1-logloss:0.24117
# [171]	validation_0-logloss:0.01308	validation_1-logloss:0.24126
# [172]	validation_0-logloss:0.01299	validation_1-logloss:0.24046
# [173]	validation_0-logloss:0.01292	validation_1-logloss:0.23993
# [174]	validation_0-logloss:0.01284	validation_1-logloss:0.23985
# [175]	validation_0-logloss:0.01275	validation_1-logloss:0.23994
# [176]	validation_0-logloss:0.01268	validation_1-logloss:0.23986
# [177]	validation_0-logloss:0.01260	validation_1-logloss:0.23996
# [178]	validation_0-logloss:0.01253	validation_1-logloss:0.23943
# [179]	validation_0-logloss:0.01243	validation_1-logloss:0.23847
# [180]	validation_0-logloss:0.01236	validation_1-logloss:0.23842
# [181]	validation_0-logloss:0.01226	validation_1-logloss:0.23885
# [182]	validation_0-logloss:0.01220	validation_1-logloss:0.23828
# [183]	validation_0-logloss:0.01214	validation_1-logloss:0.23892
# [184]	validation_0-logloss:0.01205	validation_1-logloss:0.23804
# [185]	validation_0-logloss:0.01198	validation_1-logloss:0.23799
# [186]	validation_0-logloss:0.01191	validation_1-logloss:0.23809
# [187]	validation_0-logloss:0.01185	validation_1-logloss:0.23752
# [188]	validation_0-logloss:0.01176	validation_1-logloss:0.23662
# [189]	validation_0-logloss:0.01170	validation_1-logloss:0.23659
# [190]	validation_0-logloss:0.01163	validation_1-logloss:0.23668
# [191]	validation_0-logloss:0.01157	validation_1-logloss:0.23732
# [192]	validation_0-logloss:0.01152	validation_1-logloss:0.23726
# [193]	validation_0-logloss:0.01146	validation_1-logloss:0.23722
# [194]	validation_0-logloss:0.01141	validation_1-logloss:0.23715
# [195]	validation_0-logloss:0.01136	validation_1-logloss:0.23661
# [196]	validation_0-logloss:0.01128	validation_1-logloss:0.23673
# [197]	validation_0-logloss:0.01126	validation_1-logloss:0.23651
# [198]	validation_0-logloss:0.01120	validation_1-logloss:0.23628
# [199]	validation_0-logloss:0.01113	validation_1-logloss:0.23641
# [200]	validation_0-logloss:0.01108	validation_1-logloss:0.23554
# [201]	validation_0-logloss:0.01103	validation_1-logloss:0.23533
# [202]	validation_0-logloss:0.01097	validation_1-logloss:0.23543
# [203]	validation_0-logloss:0.01091	validation_1-logloss:0.23546
# [204]	validation_0-logloss:0.01086	validation_1-logloss:0.23588
# [205]	validation_0-logloss:0.01079	validation_1-logloss:0.23600
# [206]	validation_0-logloss:0.01074	validation_1-logloss:0.23578
# [207]	validation_0-logloss:0.01069	validation_1-logloss:0.23597
# [208]	validation_0-logloss:0.01064	validation_1-logloss:0.23601
# [209]	validation_0-logloss:0.01058	validation_1-logloss:0.23613
# [210]	validation_0-logloss:0.01054	validation_1-logloss:0.23592
# [211]	validation_0-logloss:0.01047	validation_1-logloss:0.23605
# [212]	validation_0-logloss:0.01045	validation_1-logloss:0.23586
# [213]	validation_0-logloss:0.01041	validation_1-logloss:0.23626
# [214]	validation_0-logloss:0.01036	validation_1-logloss:0.23646
# [215]	validation_0-logloss:0.01031	validation_1-logloss:0.23649
# [216]	validation_0-logloss:0.01026	validation_1-logloss:0.23697
# [217]	validation_0-logloss:0.01024	validation_1-logloss:0.23679
# [218]	validation_0-logloss:0.01019	validation_1-logloss:0.23689
# [219]	validation_0-logloss:0.01014	validation_1-logloss:0.23693
# [220]	validation_0-logloss:0.01011	validation_1-logloss:0.23714
# [221]	validation_0-logloss:0.01006	validation_1-logloss:0.23732
# [222]	validation_0-logloss:0.01004	validation_1-logloss:0.23714
# [223]	validation_0-logloss:0.01001	validation_1-logloss:0.23736
# [224]	validation_0-logloss:0.00999	validation_1-logloss:0.23711
# [225]	validation_0-logloss:0.00997	validation_1-logloss:0.23703
# [226]	validation_0-logloss:0.00994	validation_1-logloss:0.23757
# [227]	validation_0-logloss:0.00992	validation_1-logloss:0.23740
# [228]	validation_0-logloss:0.00986	validation_1-logloss:0.23673
# [229]	validation_0-logloss:0.00984	validation_1-logloss:0.23649
# [230]	validation_0-logloss:0.00981	validation_1-logloss:0.23670
# [231]	validation_0-logloss:0.00979	validation_1-logloss:0.23653
# [232]	validation_0-logloss:0.00975	validation_1-logloss:0.23671
# [233]	validation_0-logloss:0.00971	validation_1-logloss:0.23674
# [234]	validation_0-logloss:0.00968	validation_1-logloss:0.23696
# [235]	validation_0-logloss:0.00966	validation_1-logloss:0.23673
# [236]	validation_0-logloss:0.00964	validation_1-logloss:0.23656
# [237]	validation_0-logloss:0.00961	validation_1-logloss:0.23708
# [238]	validation_0-logloss:0.00957	validation_1-logloss:0.23764
# [239]	validation_0-logloss:0.00954	validation_1-logloss:0.23766
# [240]	validation_0-logloss:0.00949	validation_1-logloss:0.23778
# [241]	validation_0-logloss:0.00948	validation_1-logloss:0.23775
# [242]	validation_0-logloss:0.00945	validation_1-logloss:0.23796
# [243]	validation_0-logloss:0.00943	validation_1-logloss:0.23780
# [244]	validation_0-logloss:0.00941	validation_1-logloss:0.23827
# [245]	validation_0-logloss:0.00940	validation_1-logloss:0.23819
# [246]	validation_0-logloss:0.00937	validation_1-logloss:0.23840
# [247]	validation_0-logloss:0.00935	validation_1-logloss:0.23838
# [248]	validation_0-logloss:0.00933	validation_1-logloss:0.23821
# [249]	validation_0-logloss:0.00931	validation_1-logloss:0.23872
# [250]	validation_0-logloss:0.00925	validation_1-logloss:0.23805
# [251]	validation_0-logloss:0.00924	validation_1-logloss:0.23783
# [252]	validation_0-logloss:0.00920	validation_1-logloss:0.23757
# [253]	validation_0-logloss:0.00918	validation_1-logloss:0.23750
# [254]	validation_0-logloss:0.00915	validation_1-logloss:0.23794
# [255]	validation_0-logloss:0.00911	validation_1-logloss:0.23847
# [256]	validation_0-logloss:0.00908	validation_1-logloss:0.23850
# [257]	validation_0-logloss:0.00906	validation_1-logloss:0.23894
# [258]	validation_0-logloss:0.00905	validation_1-logloss:0.23878
# [259]	validation_0-logloss:0.00903	validation_1-logloss:0.23876
# [260]	validation_0-logloss:0.00900	validation_1-logloss:0.23886
# [261]	validation_0-logloss:0.00898	validation_1-logloss:0.23931
# [262]	validation_0-logloss:0.00897	validation_1-logloss:0.23910
# [263]	validation_0-logloss:0.00895	validation_1-logloss:0.23953
# [264]	validation_0-logloss:0.00894	validation_1-logloss:0.23937
# [265]	validation_0-logloss:0.00892	validation_1-logloss:0.23935
# [266]	validation_0-logloss:0.00889	validation_1-logloss:0.23978
# [267]	validation_0-logloss:0.00887	validation_1-logloss:0.24022
# [268]	validation_0-logloss:0.00886	validation_1-logloss:0.24006
# [269]	validation_0-logloss:0.00884	validation_1-logloss:0.23984
# [270]	validation_0-logloss:0.00883	validation_1-logloss:0.24028
# [271]	validation_0-logloss:0.00881	validation_1-logloss:0.24013
# [272]	validation_0-logloss:0.00880	validation_1-logloss:0.24056
# [273]	validation_0-logloss:0.00879	validation_1-logloss:0.24048
# [274]	validation_0-logloss:0.00875	validation_1-logloss:0.24058
# [275]	validation_0-logloss:0.00874	validation_1-logloss:0.24056
# [276]	validation_0-logloss:0.00869	validation_1-logloss:0.23980
# [277]	validation_0-logloss:0.00868	validation_1-logloss:0.24023
# [278]	validation_0-logloss:0.00867	validation_1-logloss:0.24002
# [279]	validation_0-logloss:0.00865	validation_1-logloss:0.23987
# [280]	validation_0-logloss:0.00862	validation_1-logloss:0.23997
# [281]	validation_0-logloss:0.00861	validation_1-logloss:0.24040
# [282]	validation_0-logloss:0.00859	validation_1-logloss:0.24038
# [283]	validation_0-logloss:0.00858	validation_1-logloss:0.24019
# [284]	validation_0-logloss:0.00857	validation_1-logloss:0.24061
# [285]	validation_0-logloss:0.00856	validation_1-logloss:0.24065
# [286]	validation_0-logloss:0.00852	validation_1-logloss:0.23993
# [287]	validation_0-logloss:0.00851	validation_1-logloss:0.23990
# [288]	validation_0-logloss:0.00849	validation_1-logloss:0.23972
# [289]	validation_0-logloss:0.00848	validation_1-logloss:0.24002
# [290]	validation_0-logloss:0.00847	validation_1-logloss:0.23982
# [291]	validation_0-logloss:0.00845	validation_1-logloss:0.23966
# [292]	validation_0-logloss:0.00844	validation_1-logloss:0.24008
# [293]	validation_0-logloss:0.00843	validation_1-logloss:0.23954
# [294]	validation_0-logloss:0.00842	validation_1-logloss:0.23959
# [295]	validation_0-logloss:0.00840	validation_1-logloss:0.23999
# [296]	validation_0-logloss:0.00839	validation_1-logloss:0.23997
# [297]	validation_0-logloss:0.00838	validation_1-logloss:0.23979
# [298]	validation_0-logloss:0.00837	validation_1-logloss:0.24009
# [299]	validation_0-logloss:0.00835	validation_1-logloss:0.24007
# [300]	validation_0-logloss:0.00834	validation_1-logloss:0.24048
# [301]	validation_0-logloss:0.00833	validation_1-logloss:0.23994
# [302]	validation_0-logloss:0.00832	validation_1-logloss:0.23998
# [303]	validation_0-logloss:0.00831	validation_1-logloss:0.23945
# [304]	validation_0-logloss:0.00829	validation_1-logloss:0.23946
# [305]	validation_0-logloss:0.00828	validation_1-logloss:0.23986
# [306]	validation_0-logloss:0.00827	validation_1-logloss:0.23971
# [307]	validation_0-logloss:0.00826	validation_1-logloss:0.23984
# [308]	validation_0-logloss:0.00825	validation_1-logloss:0.23964
# [309]	validation_0-logloss:0.00823	validation_1-logloss:0.23911
# [310]	validation_0-logloss:0.00822	validation_1-logloss:0.23952
# [311]	validation_0-logloss:0.00821	validation_1-logloss:0.23945
# [312]	validation_0-logloss:0.00820	validation_1-logloss:0.23985
# [313]	validation_0-logloss:0.00819	validation_1-logloss:0.23970
# [314]	validation_0-logloss:0.00818	validation_1-logloss:0.23968
# [315]	validation_0-logloss:0.00816	validation_1-logloss:0.24008
# [316]	validation_0-logloss:0.00815	validation_1-logloss:0.23991
# [317]	validation_0-logloss:0.00814	validation_1-logloss:0.24003
# [318]	validation_0-logloss:0.00813	validation_1-logloss:0.23983
# [319]	validation_0-logloss:0.00812	validation_1-logloss:0.23969
# [320]	validation_0-logloss:0.00811	validation_1-logloss:0.23967
# [321]	validation_0-logloss:0.00810	validation_1-logloss:0.23922
# [322]	validation_0-logloss:0.00808	validation_1-logloss:0.23935
# [323]	validation_0-logloss:0.00807	validation_1-logloss:0.23974
# [324]	validation_0-logloss:0.00806	validation_1-logloss:0.23973
# [325]	validation_0-logloss:0.00805	validation_1-logloss:0.23956
# [326]	validation_0-logloss:0.00804	validation_1-logloss:0.23954
# [327]	validation_0-logloss:0.00803	validation_1-logloss:0.23946
# [328]	validation_0-logloss:0.00802	validation_1-logloss:0.23898
# [329]	validation_0-logloss:0.00801	validation_1-logloss:0.23937
# [330]	validation_0-logloss:0.00800	validation_1-logloss:0.23936
# [331]	validation_0-logloss:0.00799	validation_1-logloss:0.23922
# [332]	validation_0-logloss:0.00798	validation_1-logloss:0.23961
# [333]	validation_0-logloss:0.00796	validation_1-logloss:0.23941
# [334]	validation_0-logloss:0.00795	validation_1-logloss:0.23953
# [335]	validation_0-logloss:0.00794	validation_1-logloss:0.23905
# [336]	validation_0-logloss:0.00793	validation_1-logloss:0.23903
# [337]	validation_0-logloss:0.00792	validation_1-logloss:0.23890
# [338]	validation_0-logloss:0.00791	validation_1-logloss:0.23928
# [339]	validation_0-logloss:0.00790	validation_1-logloss:0.23909
# [340]	validation_0-logloss:0.00789	validation_1-logloss:0.23902
# [341]	validation_0-logloss:0.00788	validation_1-logloss:0.23941
# [342]	validation_0-logloss:0.00787	validation_1-logloss:0.23898
# [343]	validation_0-logloss:0.00786	validation_1-logloss:0.23910
# [344]	validation_0-logloss:0.00785	validation_1-logloss:0.23897
# [345]	validation_0-logloss:0.00784	validation_1-logloss:0.23895
# [346]	validation_0-logloss:0.00783	validation_1-logloss:0.23893
# [347]	validation_0-logloss:0.00782	validation_1-logloss:0.23877
# [348]	validation_0-logloss:0.00781	validation_1-logloss:0.23916
# [349]	validation_0-logloss:0.00780	validation_1-logloss:0.23914
# [350]	validation_0-logloss:0.00779	validation_1-logloss:0.23868
# [351]	validation_0-logloss:0.00778	validation_1-logloss:0.23866
# [352]	validation_0-logloss:0.00777	validation_1-logloss:0.23904
# [353]	validation_0-logloss:0.00776	validation_1-logloss:0.23897
# [354]	validation_0-logloss:0.00775	validation_1-logloss:0.23855
# [355]	validation_0-logloss:0.00774	validation_1-logloss:0.23867
# [356]	validation_0-logloss:0.00773	validation_1-logloss:0.23905
# [357]	validation_0-logloss:0.00772	validation_1-logloss:0.23892
# [358]	validation_0-logloss:0.00771	validation_1-logloss:0.23873
# [359]	validation_0-logloss:0.00770	validation_1-logloss:0.23872
# [360]	validation_0-logloss:0.00769	validation_1-logloss:0.23856
# [361]	validation_0-logloss:0.00768	validation_1-logloss:0.23855
# [362]	validation_0-logloss:0.00767	validation_1-logloss:0.23893
# [363]	validation_0-logloss:0.00766	validation_1-logloss:0.23851
# [364]	validation_0-logloss:0.00765	validation_1-logloss:0.23863
# [365]	validation_0-logloss:0.00764	validation_1-logloss:0.23850
# [366]	validation_0-logloss:0.00763	validation_1-logloss:0.23849
# [367]	validation_0-logloss:0.00762	validation_1-logloss:0.23830
# [368]	validation_0-logloss:0.00761	validation_1-logloss:0.23824
# [369]	validation_0-logloss:0.00760	validation_1-logloss:0.23860
# [370]	validation_0-logloss:0.00759	validation_1-logloss:0.23815
# [371]	validation_0-logloss:0.00758	validation_1-logloss:0.23814
# [372]	validation_0-logloss:0.00757	validation_1-logloss:0.23813
# [373]	validation_0-logloss:0.00757	validation_1-logloss:0.23798
# [374]	validation_0-logloss:0.00756	validation_1-logloss:0.23812
# [375]	validation_0-logloss:0.00755	validation_1-logloss:0.23768
# [376]	validation_0-logloss:0.00754	validation_1-logloss:0.23767
# [377]	validation_0-logloss:0.00753	validation_1-logloss:0.23766
# [378]	validation_0-logloss:0.00752	validation_1-logloss:0.23802
# [379]	validation_0-logloss:0.00751	validation_1-logloss:0.23795
# [380]	validation_0-logloss:0.00750	validation_1-logloss:0.23755
# [381]	validation_0-logloss:0.00749	validation_1-logloss:0.23770
# [382]	validation_0-logloss:0.00748	validation_1-logloss:0.23752
# [383]	validation_0-logloss:0.00747	validation_1-logloss:0.23751
# [384]	validation_0-logloss:0.00747	validation_1-logloss:0.23738
# [385]	validation_0-logloss:0.00746	validation_1-logloss:0.23774
# [386]	validation_0-logloss:0.00745	validation_1-logloss:0.23734
# [387]	validation_0-logloss:0.00744	validation_1-logloss:0.23733
# [388]	validation_0-logloss:0.00743	validation_1-logloss:0.23732
# [389]	validation_0-logloss:0.00742	validation_1-logloss:0.23726
# [390]	validation_0-logloss:0.00741	validation_1-logloss:0.23683
# [391]	validation_0-logloss:0.00740	validation_1-logloss:0.23697
# [392]	validation_0-logloss:0.00740	validation_1-logloss:0.23733
# [393]	validation_0-logloss:0.00739	validation_1-logloss:0.23694
# [394]	validation_0-logloss:0.00738	validation_1-logloss:0.23693
# [395]	validation_0-logloss:0.00737	validation_1-logloss:0.23707
# [396]	validation_0-logloss:0.00736	validation_1-logloss:0.23664
# [397]	validation_0-logloss:0.00735	validation_1-logloss:0.23658
# [398]	validation_0-logloss:0.00735	validation_1-logloss:0.23672
# [399]	validation_0-logloss:0.00734	validation_1-logloss:0.23630

# %%
get_clf_eval(y_test , ws50_preds, ws50_pred_proba)
# Out:
# 오차 행렬
# [[35  2]
#  [ 2 75]]
# 정확도: 0.9649, 정밀도: 0.9740, 재현율: 0.9740,    F1: 0.9740, AUC:0.9965

# %%
xgb_wrapper.fit(X_train, y_train, eval_set=evals,verbose=True)

ws10_preds = xgb_wrapper.predict(X_test)
ws10_pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]
get_clf_eval(y_test , ws10_preds, ws10_pred_proba)
# Out:
# [0]	validation_0-logloss:0.62456	validation_1-logloss:0.62158
# [1]	validation_0-logloss:0.58665	validation_1-logloss:0.59139
# [2]	validation_0-logloss:0.55183	validation_1-logloss:0.56009
# [3]	validation_0-logloss:0.52052	validation_1-logloss:0.53465
# [4]	validation_0-logloss:0.49177	validation_1-logloss:0.51265
# [5]	validation_0-logloss:0.46552	validation_1-logloss:0.49116
# [6]	validation_0-logloss:0.44048	validation_1-logloss:0.47068
# [7]	validation_0-logloss:0.41739	validation_1-logloss:0.44938
# [8]	validation_0-logloss:0.39592	validation_1-logloss:0.43168
# [9]	validation_0-logloss:0.37589	validation_1-logloss:0.41667
# [10]	validation_0-logloss:0.35726	validation_1-logloss:0.39896
# [11]	validation_0-logloss:0.34026	validation_1-logloss:0.38193
# [12]	validation_0-logloss:0.32406	validation_1-logloss:0.36673
# [13]	validation_0-logloss:0.30894	validation_1-logloss:0.35399
# [14]	validation_0-logloss:0.29484	validation_1-logloss:0.34209
# [15]	validation_0-logloss:0.28146	validation_1-logloss:0.32900
# [16]	validation_0-logloss:0.26891	validation_1-logloss:0.31939
# [17]	validation_0-logloss:0.25711	validation_1-logloss:0.30774
# [18]	validation_0-logloss:0.24613	validation_1-logloss:0.29784
# [19]	validation_0-logloss:0.23575	validation_1-logloss:0.28843
# [20]	validation_0-logloss:0.22576	validation_1-logloss:0.27913
# [21]	validation_0-logloss:0.21657	validation_1-logloss:0.27029
# [22]	validation_0-logloss:0.20767	validation_1-logloss:0.26204
# [23]	validation_0-logloss:0.19931	validation_1-logloss:0.25519
# [24]	validation_0-logloss:0.19129	validation_1-logloss:0.24802
# [25]	validation_0-logloss:0.18395	validation_1-logloss:0.24074
# [26]	validation_0-logloss:0.17689	validation_1-logloss:0.23456
# [27]	validation_0-logloss:0.17035	validation_1-logloss:0.22840
# [28]	validation_0-logloss:0.16403	validation_1-logloss:0.22229
# [29]	validation_0-logloss:0.15798	validation_1-logloss:0.21689
# [30]	validation_0-logloss:0.15232	validation_1-logloss:0.20991
# [31]	validation_0-logloss:0.14662	validation_1-logloss:0.20409
# [32]	validation_0-logloss:0.14123	validation_1-logloss:0.19828
# [33]	validation_0-logloss:0.13631	validation_1-logloss:0.19266
# [34]	validation_0-logloss:0.13162	validation_1-logloss:0.18767
# [35]	validation_0-logloss:0.12723	validation_1-logloss:0.18337
# [36]	validation_0-logloss:0.12303	validation_1-logloss:0.17848
# [37]	validation_0-logloss:0.11880	validation_1-logloss:0.17328
# [38]	validation_0-logloss:0.11488	validation_1-logloss:0.16884
# [39]	validation_0-logloss:0.11097	validation_1-logloss:0.16462
# [40]	validation_0-logloss:0.10734	validation_1-logloss:0.16133
# [41]	validation_0-logloss:0.10386	validation_1-logloss:0.15695
# [42]	validation_0-logloss:0.10071	validation_1-logloss:0.15362
# [43]	validation_0-logloss:0.09757	validation_1-logloss:0.14961
# [44]	validation_0-logloss:0.09449	validation_1-logloss:0.14611
# [45]	validation_0-logloss:0.09162	validation_1-logloss:0.14358
# [46]	validation_0-logloss:0.08889	validation_1-logloss:0.13935
# [47]	validation_0-logloss:0.08622	validation_1-logloss:0.13546
# [48]	validation_0-logloss:0.08369	validation_1-logloss:0.13211
# [49]	validation_0-logloss:0.08128	validation_1-logloss:0.12931
# [50]	validation_0-logloss:0.07899	validation_1-logloss:0.12598
# [51]	validation_0-logloss:0.07676	validation_1-logloss:0.12264
# [52]	validation_0-logloss:0.07467	validation_1-logloss:0.11958
# [53]	validation_0-logloss:0.07285	validation_1-logloss:0.11728
# [54]	validation_0-logloss:0.07075	validation_1-logloss:0.11488
# [55]	validation_0-logloss:0.06893	validation_1-logloss:0.11213
# [56]	validation_0-logloss:0.06705	validation_1-logloss:0.10920
# [57]	validation_0-logloss:0.06520	validation_1-logloss:0.10704
# [58]	validation_0-logloss:0.06346	validation_1-logloss:0.10439
# [59]	validation_0-logloss:0.06183	validation_1-logloss:0.10177
# [60]	validation_0-logloss:0.06021	validation_1-logloss:0.10000
# [61]	validation_0-logloss:0.05872	validation_1-logloss:0.09826
# [62]	validation_0-logloss:0.05739	validation_1-logloss:0.09681
# [63]	validation_0-logloss:0.05608	validation_1-logloss:0.09421
# [64]	validation_0-logloss:0.05467	validation_1-logloss:0.09270
# [65]	validation_0-logloss:0.05343	validation_1-logloss:0.09093
# [66]	validation_0-logloss:0.05213	validation_1-logloss:0.08954
# [67]	validation_0-logloss:0.05097	validation_1-logloss:0.08769
# [68]	validation_0-logloss:0.04988	validation_1-logloss:0.08647
# [69]	validation_0-logloss:0.04850	validation_1-logloss:0.08485
# [70]	validation_0-logloss:0.04732	validation_1-logloss:0.08256
# [71]	validation_0-logloss:0.04637	validation_1-logloss:0.08156
# [72]	validation_0-logloss:0.04545	validation_1-logloss:0.07958
# [73]	validation_0-logloss:0.04443	validation_1-logloss:0.07844
# [74]	validation_0-logloss:0.04359	validation_1-logloss:0.07660
# [75]	validation_0-logloss:0.04259	validation_1-logloss:0.07571
# [76]	validation_0-logloss:0.04183	validation_1-logloss:0.07457
# [77]	validation_0-logloss:0.04086	validation_1-logloss:0.07257
# [78]	validation_0-logloss:0.04012	validation_1-logloss:0.07184
# [79]	validation_0-logloss:0.03924	validation_1-logloss:0.07103
# [80]	validation_0-logloss:0.03845	validation_1-logloss:0.07047
# [81]	validation_0-logloss:0.03770	validation_1-logloss:0.06995
# [82]	validation_0-logloss:0.03697	validation_1-logloss:0.06914
# [83]	validation_0-logloss:0.03626	validation_1-logloss:0.06782
# [84]	validation_0-logloss:0.03567	validation_1-logloss:0.06650
# [85]	validation_0-logloss:0.03504	validation_1-logloss:0.06554
# [86]	validation_0-logloss:0.03436	validation_1-logloss:0.06451
# [87]	validation_0-logloss:0.03372	validation_1-logloss:0.06353
# [88]	validation_0-logloss:0.03294	validation_1-logloss:0.06265
# [89]	validation_0-logloss:0.03231	validation_1-logloss:0.06132
# [90]	validation_0-logloss:0.03175	validation_1-logloss:0.06037
# [91]	validation_0-logloss:0.03127	validation_1-logloss:0.05925
# [92]	validation_0-logloss:0.03072	validation_1-logloss:0.05824
# [93]	validation_0-logloss:0.03017	validation_1-logloss:0.05765
# [94]	validation_0-logloss:0.02953	validation_1-logloss:0.05667
# [95]	validation_0-logloss:0.02900	validation_1-logloss:0.05584
# [96]	validation_0-logloss:0.02852	validation_1-logloss:0.05493
# [97]	validation_0-logloss:0.02808	validation_1-logloss:0.05358
# [98]	validation_0-logloss:0.02769	validation_1-logloss:0.05265
# [99]	validation_0-logloss:0.02722	validation_1-logloss:0.05195
# [100]	validation_0-logloss:0.02668	validation_1-logloss:0.05135
# [101]	validation_0-logloss:0.02626	validation_1-logloss:0.05067
# [102]	validation_0-logloss:0.02572	validation_1-logloss:0.05003
# [103]	validation_0-logloss:0.02530	validation_1-logloss:0.04936
# [104]	validation_0-logloss:0.02485	validation_1-logloss:0.04832
# [105]	validation_0-logloss:0.02453	validation_1-logloss:0.04753
# [106]	validation_0-logloss:0.02419	validation_1-logloss:0.04680
# [107]	validation_0-logloss:0.02381	validation_1-logloss:0.04617
# [108]	validation_0-logloss:0.02336	validation_1-logloss:0.04576
# [109]	validation_0-logloss:0.02302	validation_1-logloss:0.04513
# [110]	validation_0-logloss:0.02267	validation_1-logloss:0.04447
# [111]	validation_0-logloss:0.02227	validation_1-logloss:0.04404
# [112]	validation_0-logloss:0.02196	validation_1-logloss:0.04318
# [113]	validation_0-logloss:0.02168	validation_1-logloss:0.04260
# [114]	validation_0-logloss:0.02142	validation_1-logloss:0.04189
# [115]	validation_0-logloss:0.02111	validation_1-logloss:0.04139
# [116]	validation_0-logloss:0.02085	validation_1-logloss:0.04088
# [117]	validation_0-logloss:0.02048	validation_1-logloss:0.04058
# [118]	validation_0-logloss:0.02023	validation_1-logloss:0.04008
# [119]	validation_0-logloss:0.01988	validation_1-logloss:0.03981
# [120]	validation_0-logloss:0.01963	validation_1-logloss:0.03897
# [121]	validation_0-logloss:0.01934	validation_1-logloss:0.03854
# [122]	validation_0-logloss:0.01908	validation_1-logloss:0.03806
# [123]	validation_0-logloss:0.01883	validation_1-logloss:0.03736
# [124]	validation_0-logloss:0.01854	validation_1-logloss:0.03709
# [125]	validation_0-logloss:0.01830	validation_1-logloss:0.03666
# [126]	validation_0-logloss:0.01809	validation_1-logloss:0.03624
# [127]	validation_0-logloss:0.01785	validation_1-logloss:0.03584
# [128]	validation_0-logloss:0.01766	validation_1-logloss:0.03537
# [129]	validation_0-logloss:0.01743	validation_1-logloss:0.03503
# [130]	validation_0-logloss:0.01718	validation_1-logloss:0.03485
# [131]	validation_0-logloss:0.01699	validation_1-logloss:0.03448
# [132]	validation_0-logloss:0.01678	validation_1-logloss:0.03416
# [133]	validation_0-logloss:0.01659	validation_1-logloss:0.03352
# [134]	validation_0-logloss:0.01637	validation_1-logloss:0.03331
# [135]	validation_0-logloss:0.01620	validation_1-logloss:0.03300
# [136]	validation_0-logloss:0.01607	validation_1-logloss:0.03285
# [137]	validation_0-logloss:0.01589	validation_1-logloss:0.03258
# [138]	validation_0-logloss:0.01572	validation_1-logloss:0.03231
# [139]	validation_0-logloss:0.01560	validation_1-logloss:0.03215
# [140]	validation_0-logloss:0.01544	validation_1-logloss:0.03188
# [141]	validation_0-logloss:0.01528	validation_1-logloss:0.03164
# [142]	validation_0-logloss:0.01512	validation_1-logloss:0.03142
# [143]	validation_0-logloss:0.01496	validation_1-logloss:0.03085
# [144]	validation_0-logloss:0.01481	validation_1-logloss:0.03061
# [145]	validation_0-logloss:0.01463	validation_1-logloss:0.03046
# [146]	validation_0-logloss:0.01449	validation_1-logloss:0.03037
# [147]	validation_0-logloss:0.01435	validation_1-logloss:0.03017
# [148]	validation_0-logloss:0.01421	validation_1-logloss:0.03010
# [149]	validation_0-logloss:0.01407	validation_1-logloss:0.02976
# [150]	validation_0-logloss:0.01395	validation_1-logloss:0.02955
# [151]	validation_0-logloss:0.01383	validation_1-logloss:0.02937
# [152]	validation_0-logloss:0.01369	validation_1-logloss:0.02915
# [153]	validation_0-logloss:0.01362	validation_1-logloss:0.02893
# [154]	validation_0-logloss:0.01352	validation_1-logloss:0.02891
# [155]	validation_0-logloss:0.01335	validation_1-logloss:0.02876
# [156]	validation_0-logloss:0.01323	validation_1-logloss:0.02856
# [157]	validation_0-logloss:0.01311	validation_1-logloss:0.02848
# [158]	validation_0-logloss:0.01303	validation_1-logloss:0.02824
# [159]	validation_0-logloss:0.01294	validation_1-logloss:0.02821
# [160]	validation_0-logloss:0.01279	validation_1-logloss:0.02776
# [161]	validation_0-logloss:0.01268	validation_1-logloss:0.02773
# [162]	validation_0-logloss:0.01259	validation_1-logloss:0.02751
# [163]	validation_0-logloss:0.01249	validation_1-logloss:0.02748
# [164]	validation_0-logloss:0.01237	validation_1-logloss:0.02729
# [165]	validation_0-logloss:0.01232	validation_1-logloss:0.02710
# [166]	validation_0-logloss:0.01222	validation_1-logloss:0.02677
# [167]	validation_0-logloss:0.01213	validation_1-logloss:0.02655
# [168]	validation_0-logloss:0.01204	validation_1-logloss:0.02646
# [169]	validation_0-logloss:0.01196	validation_1-logloss:0.02634
# [170]	validation_0-logloss:0.01183	validation_1-logloss:0.02625
# [171]	validation_0-logloss:0.01177	validation_1-logloss:0.02603
# [172]	validation_0-logloss:0.01167	validation_1-logloss:0.02586
# [173]	validation_0-logloss:0.01158	validation_1-logloss:0.02577
# [174]	validation_0-logloss:0.01149	validation_1-logloss:0.02547
# [175]	validation_0-logloss:0.01141	validation_1-logloss:0.02539
# [176]	validation_0-logloss:0.01136	validation_1-logloss:0.02528
# [177]	validation_0-logloss:0.01126	validation_1-logloss:0.02513
# [178]	validation_0-logloss:0.01118	validation_1-logloss:0.02505
# [179]	validation_0-logloss:0.01110	validation_1-logloss:0.02477
# [180]	validation_0-logloss:0.01103	validation_1-logloss:0.02467
# [181]	validation_0-logloss:0.01098	validation_1-logloss:0.02454
# [182]	validation_0-logloss:0.01090	validation_1-logloss:0.02446
# [183]	validation_0-logloss:0.01083	validation_1-logloss:0.02417
# [184]	validation_0-logloss:0.01075	validation_1-logloss:0.02415
# [185]	validation_0-logloss:0.01071	validation_1-logloss:0.02397
# [186]	validation_0-logloss:0.01064	validation_1-logloss:0.02371
# [187]	validation_0-logloss:0.01059	validation_1-logloss:0.02358
# [188]	validation_0-logloss:0.01051	validation_1-logloss:0.02351
# [189]	validation_0-logloss:0.01045	validation_1-logloss:0.02342
# [190]	validation_0-logloss:0.01039	validation_1-logloss:0.02315
# [191]	validation_0-logloss:0.01034	validation_1-logloss:0.02304
# [192]	validation_0-logloss:0.01026	validation_1-logloss:0.02297
# [193]	validation_0-logloss:0.01021	validation_1-logloss:0.02285
# [194]	validation_0-logloss:0.01015	validation_1-logloss:0.02260
# [195]	validation_0-logloss:0.01010	validation_1-logloss:0.02249
# [196]	validation_0-logloss:0.01004	validation_1-logloss:0.02233
# [197]	validation_0-logloss:0.01000	validation_1-logloss:0.02220
# [198]	validation_0-logloss:0.00992	validation_1-logloss:0.02209
# [199]	validation_0-logloss:0.00987	validation_1-logloss:0.02195
# [200]	validation_0-logloss:0.00981	validation_1-logloss:0.02186
# [201]	validation_0-logloss:0.00977	validation_1-logloss:0.02176
# [202]	validation_0-logloss:0.00971	validation_1-logloss:0.02153
# [203]	validation_0-logloss:0.00968	validation_1-logloss:0.02137
# [204]	validation_0-logloss:0.00963	validation_1-logloss:0.02129
# [205]	validation_0-logloss:0.00955	validation_1-logloss:0.02128
# [206]	validation_0-logloss:0.00950	validation_1-logloss:0.02114
# [207]	validation_0-logloss:0.00945	validation_1-logloss:0.02093
# [208]	validation_0-logloss:0.00941	validation_1-logloss:0.02083
# [209]	validation_0-logloss:0.00936	validation_1-logloss:0.02070
# [210]	validation_0-logloss:0.00931	validation_1-logloss:0.02050
# [211]	validation_0-logloss:0.00926	validation_1-logloss:0.02048
# [212]	validation_0-logloss:0.00921	validation_1-logloss:0.02026
# [213]	validation_0-logloss:0.00916	validation_1-logloss:0.02026
# [214]	validation_0-logloss:0.00911	validation_1-logloss:0.02019
# [215]	validation_0-logloss:0.00907	validation_1-logloss:0.02010
# [216]	validation_0-logloss:0.00903	validation_1-logloss:0.01997
# [217]	validation_0-logloss:0.00898	validation_1-logloss:0.01978
# [218]	validation_0-logloss:0.00893	validation_1-logloss:0.01979
# [219]	validation_0-logloss:0.00890	validation_1-logloss:0.01971
# [220]	validation_0-logloss:0.00886	validation_1-logloss:0.01950
# [221]	validation_0-logloss:0.00882	validation_1-logloss:0.01944
# [222]	validation_0-logloss:0.00878	validation_1-logloss:0.01935
# [223]	validation_0-logloss:0.00875	validation_1-logloss:0.01928
# [224]	validation_0-logloss:0.00871	validation_1-logloss:0.01909
# [225]	validation_0-logloss:0.00868	validation_1-logloss:0.01899
# [226]	validation_0-logloss:0.00864	validation_1-logloss:0.01899
# [227]	validation_0-logloss:0.00859	validation_1-logloss:0.01884
# [228]	validation_0-logloss:0.00855	validation_1-logloss:0.01877
# [229]	validation_0-logloss:0.00852	validation_1-logloss:0.01869
# [230]	validation_0-logloss:0.00850	validation_1-logloss:0.01867
# [231]	validation_0-logloss:0.00846	validation_1-logloss:0.01868
# [232]	validation_0-logloss:0.00841	validation_1-logloss:0.01854
# [233]	validation_0-logloss:0.00839	validation_1-logloss:0.01841
# [234]	validation_0-logloss:0.00837	validation_1-logloss:0.01832
# [235]	validation_0-logloss:0.00833	validation_1-logloss:0.01824
# [236]	validation_0-logloss:0.00830	validation_1-logloss:0.01824
# [237]	validation_0-logloss:0.00826	validation_1-logloss:0.01808
# [238]	validation_0-logloss:0.00822	validation_1-logloss:0.01802
# [239]	validation_0-logloss:0.00819	validation_1-logloss:0.01795
# [240]	validation_0-logloss:0.00817	validation_1-logloss:0.01792
# [241]	validation_0-logloss:0.00814	validation_1-logloss:0.01775
# [242]	validation_0-logloss:0.00810	validation_1-logloss:0.01775
# [243]	validation_0-logloss:0.00808	validation_1-logloss:0.01778
# [244]	validation_0-logloss:0.00804	validation_1-logloss:0.01776
# [245]	validation_0-logloss:0.00802	validation_1-logloss:0.01763
# [246]	validation_0-logloss:0.00798	validation_1-logloss:0.01751
# [247]	validation_0-logloss:0.00794	validation_1-logloss:0.01745
# [248]	validation_0-logloss:0.00791	validation_1-logloss:0.01738
# [249]	validation_0-logloss:0.00789	validation_1-logloss:0.01728
# [250]	validation_0-logloss:0.00785	validation_1-logloss:0.01713
# [251]	validation_0-logloss:0.00783	validation_1-logloss:0.01715
# [252]	validation_0-logloss:0.00779	validation_1-logloss:0.01704
# [253]	validation_0-logloss:0.00777	validation_1-logloss:0.01694
# [254]	validation_0-logloss:0.00775	validation_1-logloss:0.01686
# [255]	validation_0-logloss:0.00772	validation_1-logloss:0.01672
# [256]	validation_0-logloss:0.00770	validation_1-logloss:0.01674
# [257]	validation_0-logloss:0.00767	validation_1-logloss:0.01665
# [258]	validation_0-logloss:0.00764	validation_1-logloss:0.01654
# [259]	validation_0-logloss:0.00763	validation_1-logloss:0.01649
# [260]	validation_0-logloss:0.00761	validation_1-logloss:0.01651
# [261]	validation_0-logloss:0.00759	validation_1-logloss:0.01642
# [262]	validation_0-logloss:0.00755	validation_1-logloss:0.01632
# [263]	validation_0-logloss:0.00752	validation_1-logloss:0.01619
# [264]	validation_0-logloss:0.00750	validation_1-logloss:0.01610
# [265]	validation_0-logloss:0.00748	validation_1-logloss:0.01603
# [266]	validation_0-logloss:0.00746	validation_1-logloss:0.01590
# [267]	validation_0-logloss:0.00744	validation_1-logloss:0.01592
# [268]	validation_0-logloss:0.00741	validation_1-logloss:0.01583
# [269]	validation_0-logloss:0.00739	validation_1-logloss:0.01575
# [270]	validation_0-logloss:0.00738	validation_1-logloss:0.01570
# [271]	validation_0-logloss:0.00736	validation_1-logloss:0.01572
# [272]	validation_0-logloss:0.00733	validation_1-logloss:0.01572
# [273]	validation_0-logloss:0.00730	validation_1-logloss:0.01560
# [274]	validation_0-logloss:0.00728	validation_1-logloss:0.01552
# [275]	validation_0-logloss:0.00725	validation_1-logloss:0.01541
# [276]	validation_0-logloss:0.00724	validation_1-logloss:0.01536
# [277]	validation_0-logloss:0.00721	validation_1-logloss:0.01536
# [278]	validation_0-logloss:0.00718	validation_1-logloss:0.01527
# [279]	validation_0-logloss:0.00716	validation_1-logloss:0.01529
# [280]	validation_0-logloss:0.00715	validation_1-logloss:0.01524
# [281]	validation_0-logloss:0.00713	validation_1-logloss:0.01517
# [282]	validation_0-logloss:0.00711	validation_1-logloss:0.01506
# [283]	validation_0-logloss:0.00709	validation_1-logloss:0.01504
# [284]	validation_0-logloss:0.00707	validation_1-logloss:0.01494
# [285]	validation_0-logloss:0.00706	validation_1-logloss:0.01489
# [286]	validation_0-logloss:0.00704	validation_1-logloss:0.01491
# [287]	validation_0-logloss:0.00703	validation_1-logloss:0.01486
# [288]	validation_0-logloss:0.00701	validation_1-logloss:0.01488
# [289]	validation_0-logloss:0.00698	validation_1-logloss:0.01481
# [290]	validation_0-logloss:0.00697	validation_1-logloss:0.01474
# [291]	validation_0-logloss:0.00694	validation_1-logloss:0.01465
# [292]	validation_0-logloss:0.00693	validation_1-logloss:0.01463
# [293]	validation_0-logloss:0.00692	validation_1-logloss:0.01465
# [294]	validation_0-logloss:0.00691	validation_1-logloss:0.01460
# [295]	validation_0-logloss:0.00688	validation_1-logloss:0.01453
# [296]	validation_0-logloss:0.00686	validation_1-logloss:0.01447
# [297]	validation_0-logloss:0.00685	validation_1-logloss:0.01446
# [298]	validation_0-logloss:0.00683	validation_1-logloss:0.01447
# [299]	validation_0-logloss:0.00681	validation_1-logloss:0.01445
# [300]	validation_0-logloss:0.00681	validation_1-logloss:0.01438
# [301]	validation_0-logloss:0.00680	validation_1-logloss:0.01436
# [302]	validation_0-logloss:0.00678	validation_1-logloss:0.01438
# [303]	validation_0-logloss:0.00678	validation_1-logloss:0.01433
# [304]	validation_0-logloss:0.00677	validation_1-logloss:0.01427
# [305]	validation_0-logloss:0.00676	validation_1-logloss:0.01423
# [306]	validation_0-logloss:0.00674	validation_1-logloss:0.01424
# [307]	validation_0-logloss:0.00673	validation_1-logloss:0.01422
# [308]	validation_0-logloss:0.00673	validation_1-logloss:0.01416
# [309]	validation_0-logloss:0.00672	validation_1-logloss:0.01412
# [310]	validation_0-logloss:0.00671	validation_1-logloss:0.01414
# [311]	validation_0-logloss:0.00669	validation_1-logloss:0.01413
# [312]	validation_0-logloss:0.00669	validation_1-logloss:0.01407
# [313]	validation_0-logloss:0.00667	validation_1-logloss:0.01400
# [314]	validation_0-logloss:0.00666	validation_1-logloss:0.01399
# [315]	validation_0-logloss:0.00664	validation_1-logloss:0.01400
# [316]	validation_0-logloss:0.00663	validation_1-logloss:0.01397
# [317]	validation_0-logloss:0.00663	validation_1-logloss:0.01391
# [318]	validation_0-logloss:0.00662	validation_1-logloss:0.01390
# [319]	validation_0-logloss:0.00661	validation_1-logloss:0.01392
# [320]	validation_0-logloss:0.00660	validation_1-logloss:0.01385
# [321]	validation_0-logloss:0.00659	validation_1-logloss:0.01382
# [322]	validation_0-logloss:0.00658	validation_1-logloss:0.01383
# [323]	validation_0-logloss:0.00657	validation_1-logloss:0.01381
# [324]	validation_0-logloss:0.00657	validation_1-logloss:0.01375
# [325]	validation_0-logloss:0.00656	validation_1-logloss:0.01376
# [326]	validation_0-logloss:0.00655	validation_1-logloss:0.01373
# [327]	validation_0-logloss:0.00654	validation_1-logloss:0.01367
# [328]	validation_0-logloss:0.00653	validation_1-logloss:0.01368
# [329]	validation_0-logloss:0.00652	validation_1-logloss:0.01366
# [330]	validation_0-logloss:0.00651	validation_1-logloss:0.01362
# [331]	validation_0-logloss:0.00650	validation_1-logloss:0.01363
# [332]	validation_0-logloss:0.00650	validation_1-logloss:0.01357
# [333]	validation_0-logloss:0.00649	validation_1-logloss:0.01354
# [334]	validation_0-logloss:0.00648	validation_1-logloss:0.01355
# [335]	validation_0-logloss:0.00647	validation_1-logloss:0.01354
# [336]	validation_0-logloss:0.00647	validation_1-logloss:0.01348
# [337]	validation_0-logloss:0.00646	validation_1-logloss:0.01347
# [338]	validation_0-logloss:0.00644	validation_1-logloss:0.01349
# [339]	validation_0-logloss:0.00644	validation_1-logloss:0.01346
# [340]	validation_0-logloss:0.00643	validation_1-logloss:0.01340
# [341]	validation_0-logloss:0.00642	validation_1-logloss:0.01341
# [342]	validation_0-logloss:0.00641	validation_1-logloss:0.01340
# [343]	validation_0-logloss:0.00640	validation_1-logloss:0.01336
# [344]	validation_0-logloss:0.00640	validation_1-logloss:0.01333
# [345]	validation_0-logloss:0.00639	validation_1-logloss:0.01334
# [346]	validation_0-logloss:0.00638	validation_1-logloss:0.01334
# [347]	validation_0-logloss:0.00637	validation_1-logloss:0.01328
# [348]	validation_0-logloss:0.00637	validation_1-logloss:0.01325
# [349]	validation_0-logloss:0.00635	validation_1-logloss:0.01326
# [350]	validation_0-logloss:0.00635	validation_1-logloss:0.01323
# [351]	validation_0-logloss:0.00634	validation_1-logloss:0.01322
# [352]	validation_0-logloss:0.00633	validation_1-logloss:0.01316
# [353]	validation_0-logloss:0.00632	validation_1-logloss:0.01317
# [354]	validation_0-logloss:0.00631	validation_1-logloss:0.01316
# [355]	validation_0-logloss:0.00630	validation_1-logloss:0.01317
# [356]	validation_0-logloss:0.00630	validation_1-logloss:0.01314
# [357]	validation_0-logloss:0.00629	validation_1-logloss:0.01311
# [358]	validation_0-logloss:0.00629	validation_1-logloss:0.01305
# [359]	validation_0-logloss:0.00628	validation_1-logloss:0.01307
# [360]	validation_0-logloss:0.00627	validation_1-logloss:0.01305
# [361]	validation_0-logloss:0.00626	validation_1-logloss:0.01300
# [362]	validation_0-logloss:0.00626	validation_1-logloss:0.01297
# [363]	validation_0-logloss:0.00625	validation_1-logloss:0.01298
# [364]	validation_0-logloss:0.00624	validation_1-logloss:0.01295
# [365]	validation_0-logloss:0.00623	validation_1-logloss:0.01295
# [366]	validation_0-logloss:0.00622	validation_1-logloss:0.01296
# [367]	validation_0-logloss:0.00622	validation_1-logloss:0.01291
# [368]	validation_0-logloss:0.00621	validation_1-logloss:0.01288
# [369]	validation_0-logloss:0.00620	validation_1-logloss:0.01287
# [370]	validation_0-logloss:0.00619	validation_1-logloss:0.01288
# [371]	validation_0-logloss:0.00618	validation_1-logloss:0.01285
# [372]	validation_0-logloss:0.00618	validation_1-logloss:0.01282
# [373]	validation_0-logloss:0.00617	validation_1-logloss:0.01282
# [374]	validation_0-logloss:0.00617	validation_1-logloss:0.01277
# [375]	validation_0-logloss:0.00616	validation_1-logloss:0.01275
# [376]	validation_0-logloss:0.00615	validation_1-logloss:0.01277
# [377]	validation_0-logloss:0.00614	validation_1-logloss:0.01274
# [378]	validation_0-logloss:0.00614	validation_1-logloss:0.01269
# [379]	validation_0-logloss:0.00613	validation_1-logloss:0.01268
# [380]	validation_0-logloss:0.00612	validation_1-logloss:0.01270
# [381]	validation_0-logloss:0.00611	validation_1-logloss:0.01267
# [382]	validation_0-logloss:0.00610	validation_1-logloss:0.01266
# [383]	validation_0-logloss:0.00610	validation_1-logloss:0.01262
# [384]	validation_0-logloss:0.00609	validation_1-logloss:0.01264
# [385]	validation_0-logloss:0.00609	validation_1-logloss:0.01258
# [386]	validation_0-logloss:0.00608	validation_1-logloss:0.01257
# [387]	validation_0-logloss:0.00607	validation_1-logloss:0.01257
# [388]	validation_0-logloss:0.00607	validation_1-logloss:0.01252
# [389]	validation_0-logloss:0.00606	validation_1-logloss:0.01252
# [390]	validation_0-logloss:0.00605	validation_1-logloss:0.01253
# [391]	validation_0-logloss:0.00604	validation_1-logloss:0.01250
# [392]	validation_0-logloss:0.00603	validation_1-logloss:0.01249
# [393]	validation_0-logloss:0.00602	validation_1-logloss:0.01250
# [394]	validation_0-logloss:0.00602	validation_1-logloss:0.01244
# [395]	validation_0-logloss:0.00601	validation_1-logloss:0.01246
# [396]	validation_0-logloss:0.00601	validation_1-logloss:0.01243
# [397]	validation_0-logloss:0.00600	validation_1-logloss:0.01241
# [398]	validation_0-logloss:0.00599	validation_1-logloss:0.01243
# [399]	validation_0-logloss:0.00598	validation_1-logloss:0.01242
# 오차 행렬
# [[35  2]
#  [ 1 76]]
# 정확도: 0.9737, 정밀도: 0.9744, 재현율: 0.9870,    F1: 0.9806, AUC:0.9954

# %% [markdown]
# ### LightCBM

# %%
# LightGBM의 파이썬 패키지인 lightgbm에서 LGBMClassifier 임포트
from lightgbm import LGBMClassifier

import pandas as pd
import numpy as np
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

dataset = load_breast_cancer()

cancer_df = pd.DataFrame(data=dataset.data, columns=dataset.feature_names)
cancer_df['target']= dataset.target
X_features = cancer_df.iloc[:, :-1]
y_label = cancer_df.iloc[:, -1]

# 전체 데이터 중 80%는 학습용 데이터, 20%는 테스트용 데이터 추출
X_train, X_test, y_train, y_test=train_test_split(X_features, y_label, test_size=0.2, random_state=156 )

# 위에서 만든 X_train, y_train을 다시 쪼개서 90%는 학습과 10%는 검증용 데이터로 분리
X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=156 )

# 앞서 XGBoost와 동일하게 n_estimators는 400 설정.
lgbm_wrapper = LGBMClassifier(n_estimators=400, learning_rate=0.05)

# LightGBM도 XGBoost와 동일하게 조기 중단 수행 가능.
evals = [(X_tr, y_tr), (X_val, y_val)]
lgbm_wrapper.fit(X_tr, y_tr, eval_set=evals)
preds = lgbm_wrapper.predict(X_test)
pred_proba = lgbm_wrapper.predict_proba(X_test)[:, 1]
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 251, number of negative: 158
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002915 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4092
# [LightGBM] [Info] Number of data points in the train set: 409, number of used features: 30
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.613692 -> initscore=0.462858
# [LightGBM] [Info] Start training from score 0.462858
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %%
get_clf_eval(y_test, preds, pred_proba)
# Out:
# 오차 행렬
# [[34  3]
#  [ 2 75]]
# 정확도: 0.9561, 정밀도: 0.9615, 재현율: 0.9740,    F1: 0.9677, AUC:0.9923

# %%
from lightgbm import plot_importance
import matplotlib.pyplot as plt
# %matplotlib inline

fig, ax = plt.subplots(figsize=(10, 12))
plot_importance(lgbm_wrapper, ax=ax)
plt.savefig('lightgbm_feature_importance.tif', format='tif', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### 하이퍼 파라미터 튜닝

# %%
pip install hyperopt
# Out:
# Requirement already satisfied: hyperopt in c:\users\un747\anaconda3\lib\site-packages (0.2.7)
# Requirement already satisfied: numpy in c:\users\un747\anaconda3\lib\site-packages (from hyperopt) (1.26.4)
# Requirement already satisfied: scipy in c:\users\un747\anaconda3\lib\site-packages (from hyperopt) (1.15.1)
# Requirement already satisfied: six in c:\users\un747\anaconda3\lib\site-packages (from hyperopt) (1.16.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\un747\anaconda3\lib\site-packages (from hyperopt) (3.4.2)
# Requirement already satisfied: future in c:\users\un747\anaconda3\lib\site-packages (from hyperopt) (1.0.0)
# Requirement already satisfied: tqdm in c:\users\un747\anaconda3\lib\site-packages (from hyperopt) (4.66.5)
# Requirement already satisfied: cloudpickle in c:\users\un747\anaconda3\lib\site-packages (from hyperopt) (3.0.0)
# Requirement already satisfied: py4j in c:\users\un747\anaconda3\lib\site-packages (from hyperopt) (0.10.9.9)
# Requirement already satisfied: colorama in c:\users\un747\anaconda3\lib\site-packages (from tqdm->hyperopt) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from hyperopt import hp

# -10 ~ 10까지 1간격을 가지는 입력 변수 x와 -15 ~ 15까지 1간격으로 입력 변수 y 설정.
search_space = {'x': hp.quniform('x', -10, 10, 1), 'y': hp.quniform('y', -15, 15, 1) }

# %%
from hyperopt import STATUS_OK

# 목적 함수를 생성. 변숫값과 변수 검색 공간을 가지는 딕셔너리를 인자로 받고, 특정 값을 반환
def objective_func(search_space):
    x = search_space['x']
    y = search_space['y']
    retval = x**2 - 20*y
    
    return retval

# %%
from hyperopt import fmin, tpe, Trials
import numpy as np

# 입력 결괏값을 저장한 Trials 객체값 생성.
trial_val = Trials()

# 목적 함수의 최솟값을 반환하는 최적 입력 변숫값을 5번의 입력값 시도(max_evals=5)로 찾아냄.
best_01 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=5
               , trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_01)
# Out:
# 100%|█████████████████████████████████████████████████████████████| 5/5 [00:00<00:00, 283.16trial/s, best loss: -224.0]
# best: {'x': -4.0, 'y': 12.0}

# %%
trial_val = Trials()

# max_evals를 20회로 늘려서 재테스트
best_02 = fmin(fn=objective_func, space=search_space, algo=tpe.suggest, max_evals=20
               , trials=trial_val, rstate=np.random.default_rng(seed=0))
print('best:', best_02)
# Out:
# 100%|███████████████████████████████████████████████████████████| 20/20 [00:00<00:00, 391.14trial/s, best loss: -296.0]
# best: {'x': 2.0, 'y': 15.0}

# %%
print(trial_val.results)
print(trial_val.vals)
# Out:
# [{'loss': -64.0, 'status': 'ok'}, {'loss': -184.0, 'status': 'ok'}, {'loss': 56.0, 'status': 'ok'}, {'loss': -224.0, 'status': 'ok'}, {'loss': 61.0, 'status': 'ok'}, {'loss': -296.0, 'status': 'ok'}, {'loss': -40.0, 'status': 'ok'}, {'loss': 281.0, 'status': 'ok'}, {'loss': 64.0, 'status': 'ok'}, {'loss': 100.0, 'status': 'ok'}, {'loss': 60.0, 'status': 'ok'}, {'loss': -39.0, 'status': 'ok'}, {'loss': 1.0, 'status': 'ok'}, {'loss': -164.0, 'status': 'ok'}, {'loss': 21.0, 'status': 'ok'}, {'loss': -56.0, 'status': 'ok'}, {'loss': 284.0, 'status': 'ok'}, {'loss': 176.0, 'status': 'ok'}, {'loss': -171.0, 'status': 'ok'}, {'loss': 0.0, 'status': 'ok'}]
# {'x': [-6.0, -4.0, 4.0, -4.0, 9.0, 2.0, 10.0, -9.0, -8.0, -0.0, -0.0, 1.0, 9.0, 6.0, 9.0, 2.0, -2.0, -4.0, 7.0, -0.0], 'y': [5.0, 10.0, -2.0, 12.0, 1.0, 15.0, 7.0, -10.0, 0.0, -5.0, -3.0, 2.0, 4.0, 10.0, 3.0, 3.0, -14.0, -8.0, 11.0, -0.0]}

# %%
losses = [loss_dict['loss'] for loss_dict in trial_val.results]

# DataFrame으로 생성.
result_df = pd.DataFrame({'x': trial_val.vals['x'], 'y': trial_val.vals['y'], 'losses': losses})
result_df
# Out:
#        x     y  losses
# 0   -6.0   5.0   -64.0
# 1   -4.0  10.0  -184.0
# 2    4.0  -2.0    56.0
# 3   -4.0  12.0  -224.0
# 4    9.0   1.0    61.0
# 5    2.0  15.0  -296.0
# 6   10.0   7.0   -40.0
# 7   -9.0 -10.0   281.0
# 8   -8.0   0.0    64.0
# 9   -0.0  -5.0   100.0
# 10  -0.0  -3.0    60.0
# 11   1.0   2.0   -39.0
# 12   9.0   4.0     1.0
# 13   6.0  10.0  -164.0
# 14   9.0   3.0    21.0
# 15   2.0   3.0   -56.0
# 16  -2.0 -14.0   284.0
# 17  -4.0  -8.0   176.0
# 18   7.0  11.0  -171.0
# 19  -0.0  -0.0     0.0

# %%
# 전체 데이터 중 80%는 학습용 데이터, 20%는 테스트용 데이터 추출
X_train, X_test, y_train, y_test=train_test_split(X_features, y_label, test_size=0.2, random_state=156 )

# 앞에서 추출한 학습 데이터를 다시 학습과 검증 데이터로 분리
X_tr, X_val, y_tr, y_val= train_test_split(X_train, y_train, test_size=0.1, random_state=156 )

# %%
from hyperopt import hp

# max_depth는 5에서 20까지 1간격으로, min_child_weight는 1에서 2까지 1간격으로
# colsample_bytree는 0.5에서 1사이, learning_rate는 0.01에서 0.2 사이 정규 분포된 값으로 검색.
xgb_search_space = {'max_depth': hp.quniform('max_depth', 5, 20, 1), 
                    'min_child_weight': hp.quniform('min_child_weight', 1, 2, 1),
                    'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
                    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 1),
                   }

# %%
from sklearn.model_selection import cross_val_score
from xgboost import XGBClassifier
from hyperopt import STATUS_OK

# fmin()에서 입력된 search_space 값으로 입력된 모든 값은 실수형임.
# XGBClassifier의 정수형 하이퍼 파라미터는 정수형 변환을 해줘야 함.
# 정확도는 높을수록 더 좋은 수치임. -1 * 정확도를 곱해서 큰 정확도 값일수록 최소가 되도록 변환
def objective_func(search_space):
    # 수행 시간 절약을 위해 nestimators는 100으로 축소
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                            min_child_weight=int(search_space['min_child_weight']),
                            learning_rate=search_space['learning_rate'],
                            colsample_bytree=search_space['colsample_bytree'],
                            eval_metric='logloss')
    accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=3)
    
    # accuracy는 cv=3 개수만큼 roc-auc 결과를 리스트로 가짐. 이를 평균해서 반환하되 -1을 곱함.
    return {'loss':-1 * np.mean(accuracy), 'status': STATUS_OK}

# %%
from hyperopt import fmin, tpe, Trials

trial_val = Trials()
best = fmin(fn=objective_func,
            space=xgb_search_space,
            algo=tpe.suggest,
            max_evals=50, # 최대 반복 횟수를 지정합니다.
            trials=trial_val, rstate=np.random.default_rng(seed=9))
print('best:', best)
# Out:
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]
# job exception: 'super' object has no attribute '__sklearn_tags__'
#   0%|                                                                           | 0/50 [00:00<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[91], line 4
#       1 from hyperopt import fmin, tpe, Trials
#       3 trial_val = Trials()
# ----> 4 best = fmin(fn=objective_func,
#       5             space=xgb_search_space,
#       6             algo=tpe.suggest,
#       7             max_evals=50, # 최대 반복 횟수를 지정합니다.
#       8             trials=trial_val, rstate=np.random.default_rng(seed=9))
#       9 print('best:', best)
#
# File ~\anaconda3\Lib\site-packages\hyperopt\fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~\anaconda3\Lib\site-packages\hyperopt\base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~\anaconda3\Lib\site-packages\hyperopt\fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~\anaconda3\Lib\site-packages\hyperopt\fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~\anaconda3\Lib\site-packages\hyperopt\fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~\anaconda3\Lib\site-packages\hyperopt\fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~\anaconda3\Lib\site-packages\hyperopt\base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[89], line 15, in objective_func(search_space)
#       8 def objective_func(search_space):
#       9     # 수행 시간 절약을 위해 nestimators는 100으로 축소
#      10     xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
#      11                             min_child_weight=int(search_space['min_child_weight']),
#      12                             learning_rate=search_space['learning_rate'],
#      13                             colsample_bytree=search_space['colsample_bytree'],
#      14                             eval_metric='logloss')
# ---> 15     accuracy = cross_val_score(xgb_clf, X_train, y_train, scoring='accuracy', cv=3)
#      17     # accuracy는 cv=3 개수만큼 roc-auc 결과를 리스트로 가짐. 이를 평균해서 반환하되 -1을 곱함.
#      18     return {'loss':-1 * np.mean(accuracy), 'status': STATUS_OK}
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:684, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     681 # To ensure multimetric format is not supported
#     682 scorer = check_scoring(estimator, scoring=scoring)
# --> 684 cv_results = cross_validate(
#     685     estimator=estimator,
#     686     X=X,
#     687     y=y,
#     688     groups=groups,
#     689     scoring={"score": scorer},
#     690     cv=cv,
#     691     n_jobs=n_jobs,
#     692     verbose=verbose,
#     693     params=params,
#     694     pre_dispatch=pre_dispatch,
#     695     error_score=error_score,
#     696 )
#     697 return cv_results["test_score"]
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File ~\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:347, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     345 X, y = indexable(X, y)
#     346 params = {} if params is None else params
# --> 347 cv = check_cv(cv, y, classifier=is_classifier(estimator))
#     349 scorers = check_scoring(
#     350     estimator, scoring=scoring, raise_exc=(error_score == "raise")
#     351 )
#     353 if _routing_enabled():
#     354     # For estimators, a MetadataRouter is created in get_metadata_routing
#     355     # methods. For these router methods, we create the router to use
#     356     # `process_routing` on it.
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1237, in is_classifier(estimator)
#    1230     warnings.warn(
#    1231         f"passing a class to {print(inspect.stack()[0][3])} is deprecated and "
#    1232         "will be removed in 1.8. Use an instance of the class instead.",
#    1233         FutureWarning,
#    1234     )
#    1235     return getattr(estimator, "_estimator_type", None) == "classifier"
# -> 1237 return get_tags(estimator).estimator_type == "classifier"
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_tags.py:430, in get_tags(estimator)
#     428 for klass in reversed(type(estimator).mro()):
#     429     if "__sklearn_tags__" in vars(klass):
# --> 430         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431         class_order.append(klass)
#     432     elif "_more_tags" in vars(klass):
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:540, in ClassifierMixin.__sklearn_tags__(self)
#     539 def __sklearn_tags__(self):
# --> 540     tags = super().__sklearn_tags__()
#     541     tags.estimator_type = "classifier"
#     542     tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'

# %%
print('colsample_bytree:{0}, learning_rate:{1}, max_depth:{2}, min_child_weight:{3}'.format(
    round(best['colsample_bytree'], 5), round(best['learning_rate'], 5),
    int(best['max_depth']), int(best['min_child_weight'])))

# %%
xgb_wrapper = XGBClassifier(n_estimators=400,
                            learning_rate=round(best['learning_rate'], 5),
                            max_depth=int(best['max_depth']),
                            min_child_weight=int(best['min_child_weight']),
                            colsample_bytree=round(best['colsample_bytree'], 5)
                           )

evals = [(X_tr, y_tr), (X_val, y_val)]
xgb_wrapper.fit(X_tr, y_tr, early_stopping_rounds=50, eval_metric='logloss',
                eval_set=evals, verbose=True)

preds = xgb_wrapper.predict(X_test)
pred_proba = xgb_wrapper.predict_proba(X_test)[:, 1]

get_clf_eval(y_test, preds, pred_proba)
